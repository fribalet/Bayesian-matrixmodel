# %% [markdown]
# # 4 day test run for multilevel `m_pmb` (`m12u`) for new SeaFlow dataset
#  * running for first 4 days of dataset
#
# ### general information about the different growth/respiration versions
#
#  * for the functional form of the different size-dependent growth and respiration formulations see [this notebook](sizedep_formulations.ipynb)

# %% [markdown]
# ## global switches and settings

# %%
# use test data (not all data is used for fitting/training)
use_testdata = False

# create plots of the data
show_data = True

# netCDF output file (set to None to not save output)
savename_output = 'data_exp_zs_20201207_multilevel_seaflow-v4.nc'

# save the Stan output instead a few stats (only active if filename is specified above)
save_stan_output = True

# specify the Stan variable names to save; if set to None, all variables are saved 
# (only active if save_stan_output is True)
varnames_save = None

# the number of tries to fit each Stan model to achieve an R-hat < 1.1
num_tries = 3

# the number of chains to run
num_chains = 6

# the prior_only option passed to each Stan model
prior_only = False

# %% [markdown]
# ## load data from files and plot

# %%
#%matplotlib notebook
import netCDF4 as nc4
import numpy as np
import pandas as pd
import logging

# load data
datafiles = {
    'seaflow':'data/SeaFlow_PSD_hourlyCOUNT_v4_regrid-25-8_day2to5_1080min-offset.nc',
    #'zinser':'data/Zinser_SizeDist_logtransform-25-7.nc',
}

itestfiles = {
    'seaflow':'data/Zinser_SizeDist_calibrated-26-6-itest.csv', # same as zinser
    'zinser':'data/Zinser_SizeDist_calibrated-26-6-itest.csv',         
}

desc = {
    'seaflow':'SeaFlow dataset',
    'zinser':'Zinser dataset',    
}

size_units = 'fg C cell$^{-1}$'

data_gridded = {}
for dataname in datafiles:
    data_gridded[dataname] = {}
    with nc4.Dataset(datafiles[dataname]) as nc:
        for var in nc.variables:
            data_gridded[dataname][var] = nc.variables[var][:]

    # create "counts" entry
    if 'count' in data_gridded[dataname]:
        data_gridded[dataname]['counts'] = (data_gridded[dataname]['count'][None,:] * data_gridded[dataname]['w_obs']).astype(int)
    elif 'abundance' in data_gridded[dataname]:
        logging.warning('{}: Using "abundance" data to generate count data for the model.'.format(dataname))
        data_gridded[dataname]['counts'] = (data_gridded[dataname]['count'][None,:] * data_gridded[dataname]['w_obs']).astype(int)
    else:
        raise RuntimeError('Cannot find a "count" or "abundance" entry in "{}".'.format(datafiles[dataname]))
        
    
    # add description
    desc[dataname] += ' (m={data[m]}, $\Delta_v^{{-1}}$={data[delta_v_inv]})'.format(data=data_gridded[dataname])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

def add_colorbar(ax, **cbarargs):
    axins_cbar = inset_axes(ax, width='3%', height='90%', loc=5, bbox_to_anchor=(0.05,0.0,1,1), bbox_transform=ax.transAxes)
    mpl.colorbar.ColorbarBase(axins_cbar, orientation='vertical', **cbarargs)

if show_data:
    for i,dataname in enumerate(data_gridded):
        nrows = 3

        v_min = data_gridded[dataname]['v_min']
        delta_v = 1.0/data_gridded[dataname]['delta_v_inv']
        v = v_min * 2**(np.arange(data_gridded[dataname]['m'])*delta_v) 

        fig,axs = plt.subplots(nrows=nrows, sharex=True, figsize=(12,4*nrows))

        ax = axs[0]
        ax.set_title('raw '+desc[dataname], size=20)
        ax.plot(data_gridded[dataname]['time'], data_gridded[dataname]['PAR'], color='gold')
        ax.set(ylabel='PAR')

        ax = axs[1]
        pc = ax.pcolormesh(data_gridded[dataname]['time'], v, data_gridded[dataname]['w_obs'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='size class proportion')

        ax = axs[2]
        pc = ax.pcolormesh(data_gridded[dataname]['time'], v, data_gridded[dataname]['counts'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='counts')
    axs[-1].set_xlabel=('time (minutes)')
None

# %% [markdown]
# ## process data and plot it

# %%
# prepare data for Stan model

seaflow_filter_par = True

if 'data' not in globals():
    data = {}

for dataname in data_gridded:
    dt = 20 # in units of minutes
    
    data[dataname] = {'dt':dt}
    for v in ('m','v_min','delta_v_inv'):
        data[dataname][v] = data_gridded[dataname][v]

    if 'seaflow' in dataname:
        limit_days = None
        data[dataname]['obs'] = data_gridded[dataname]['w_obs']
        data[dataname]['t_obs'] = data_gridded[dataname]['time']
        if limit_days is None:
            limit_days = int(np.ceil(data[dataname]['t_obs'][-1]/1440))
        
        if seaflow_filter_par:
            # median filter PAR
            # see: medianfilter_par.ipynb
            n = len(data_gridded[dataname]['PAR'])
            wsh = 2 # half of median filter window size; window size is 2*wsh+1
            par = np.array([np.median(data_gridded[dataname]['PAR'][max(0,i-wsh):min(n,i+wsh+1)]) for i in range(n)])
        else:
            par = data_gridded[dataname]['PAR']
    else:
        limit_days = 2
        
        data[dataname]['obs'] = data_gridded[dataname]['w_obs']
        data[dataname]['t_obs'] = data_gridded[dataname]['time']
        par = data_gridded[dataname]['PAR']
        
    if limit_days > 0:
        limit_minutes = limit_days*1440
        
        ind_obs = data[dataname]['t_obs'] < limit_minutes
        
        if not np.all(ind_obs):
            print('{}: limit_days is set to {}, removing {}/{} observation times'.format(dataname, limit_days, ind_obs.size-np.count_nonzero(ind_obs), ind_obs.size))
        
        data[dataname]['t_obs'] = data[dataname]['t_obs'][ind_obs]
        data[dataname]['obs'] = data[dataname]['obs'][:,ind_obs]
        
        data[dataname]['nt'] = int(limit_minutes//data[dataname]['dt'])

    data[dataname]['nt_obs'] = data[dataname]['t_obs'].size
    
    if use_testdata:
        # load cross-validation testing indices and add them to data
        data[dataname]['i_test'] = np.loadtxt(itestfiles[dataname]).astype(int)
        # remove last index, so that dimensions agree
        data[dataname]['i_test'] = data[dataname]['i_test'][:-1]
    else:
        # set all indices to zero
        data[dataname]['i_test'] = np.zeros(data[dataname]['nt_obs'], dtype=int)
        
    # switch on or off data fitting
    data[dataname]['prior_only'] = int(prior_only)
    
    # add light data
    t = np.arange(data[dataname]['nt'])*data[dataname]['dt']
    data[dataname]['E'] = np.interp(t, xp=data_gridded[dataname]['time'], fp=par)
    
    # real count data
    data[dataname]['obs_count'] = data_gridded[dataname]['counts'][:, ind_obs]
    
    # consistency check
    if len(data[dataname]['i_test']) != data[dataname]['nt_obs']:
        raise ValueError('Invalid number of testing indices for "{}" (expected {}, got {}).'.format(dataname,data[dataname]['nt_obs'],len(data[dataname]['i_test'])))
# Out:
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/numpy/core/fromnumeric.py:746: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)

# %%
if show_data:
    for i,dataname in enumerate(data):
        nrows = 3

        v_min = data[dataname]['v_min']
        delta_v = 1.0/data[dataname]['delta_v_inv']
        v = v_min * 2**(np.arange(data[dataname]['m'])*delta_v) 
        t = np.arange(data[dataname]['nt'])*data[dataname]['dt']


        fig,axs = plt.subplots(nrows=nrows, sharex=True, figsize=(12,4*nrows))

        ax = axs[0]
        ax.set_title('processed '+desc[dataname], size=20)
        ax.plot(t, data[dataname]['E'], color='gold')
        ax.set(ylabel='E')

        ax = axs[1]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, data[dataname]['obs'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='size class proportion')
        ax.set_xlim(left=0.0)

        ax = axs[2]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, data[dataname]['obs_count'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='counts')
        ax.set_xlim(left=0.0)
    axs[-1].set_xlabel('time (minutes)')
None

# %% [markdown]
# ## run model

# %%
desc_model = {
    #'m2':'m$_{bmx}$',
    #'m4':'m$_{bmb}$',
    'm12u':'m$_{pmb}$',
    #'m15':'m$_{fmb}$',
    #'m16':'m$_{fmf}$',
    #'m4s6':'m$_{btb}$',
    #'m12us6':'m$_{ptb}$',
    #'m15s6':'m$_{ftb}$',
    #'m16s6':'m$_{ftf}$',
}
# preparing for some regular expression magic
model_code_replacements = {
    'm2':(),
    'm4':(),
    'm12u':(),
    'm15':(),
    'm16':(),
    'm4s6':(('^( *int nknots = *)','6;'),),
    'm12us6':(('^( *int nknots = *)','6;'),),
    'm15s6':(('^( *int nknots = *)','6;'),),
    'm16s6':(('^( *int nknots = *)','6;'),),
}
model_stan_key = {
    'm2':'c2',
    'm4':'c4',
    'm12u':'c12u',
    'm15':'c15',
    'm16':'c16',
    'm4s6':'c4s',
    'm12us6':'c12us',
    'm15s6':'c15s',
    'm16s6':'c16s',
}
stan_files = {
    'c12u':'stancode_gallery3/ml_daily_version/multilevel_mlmultinom_estinilnorm2_monodelta2_resp_gammaiv9_normparam_trackgrowthvol_xval2.stan',
}

# %%
import pystan
import re
import time

def get_max_rhat(fit):
    s = fit.summary()
    irhat = s['summary_colnames'].index("Rhat")
    return np.nanmax(s['summary'][:,irhat])

if 'models' not in globals():
    models = {}
if 'mcmcs' not in globals():
    mcmcs = {}
if 'maxrhats' not in globals():
    maxrhats = {}
if 'sampling_time' not in globals():
    sampling_time = {}
if 'num_tries' not in globals():
    num_tries = 3
    
try_again = True
refit_all = False

refit_required = {}
stan_base_code = {}
for key,stan_file in stan_files.items():
    with open(stan_file) as f:
        stan_base_code[key] = f.read()

stan_code = {}
for model in desc_model:
    code_split = stan_base_code[model_stan_key[model]].split('\n')
    code_split_new = []
    for line in code_split:
        line_new = line
        for replacement in model_code_replacements[model]:
            m = re.match(replacement[0],line_new)
            if m:
                line_new = m.groups(0)[0]+replacement[1]
                print('{}: patching in "{}"'.format(model, line_new))
        code_split_new.append(line_new)
                
    stan_code[model] = '\n'.join(code_split_new)

for model in desc_model:
    refit_required[model] = True
    if model in models and models[model].model_code == stan_code[model]:
        print('{}: unchanged code, not recompiling'.format(model))
        refit_required[model] = False
    else:
        if model in models:
            print('{}: code change detected, recompiling'.format(model))
        else:
            print('{}: compiling'.format(model))
        models[model] = pystan.StanModel(model_code=stan_code[model], model_name=model, obfuscate_model_name=False)

# run a bunch of experiments -- this may take a while
for model in models:
    if model not in maxrhats:
        maxrhats[model] = {}
    if model not in sampling_time:
        sampling_time[model] = {}
    for dataname in data:
        if dataname not in maxrhats[model]:
            maxrhats[model][dataname] = []
        if dataname not in sampling_time[model]:
            sampling_time[model][dataname] = []
        if model in mcmcs:
            if dataname in mcmcs[model] and not refit_all and not refit_required[model]:
                print('{}: found existing results:'.format(model))
                print('{} ({})'.format(model, desc_model[model])) 
                print('\n'.join(x for x in mcmcs[model][dataname].__str__().split('\n') if '[' not in x or 'rho_max' in x or 'delta_max' in x or 'gamma_max' in x or 'E_star' in x or 'daily' in x))
                rhat_max = get_max_rhat(mcmcs[model][dataname])
                if try_again and rhat_max >= 1.1:
                    print('{}: found Rhat={:.3f}, trying again'.format(model,rhat_max))
                else:
                    print('{}: not re-running model'.format(model))
                    print()
                    continue
            elif refit_all:
                print('{}: refit_all is active, re-running model'.format(model))
            elif refit_required[model]:
                print('{}: change in model code requires re-running model'.format(model))
        else:
            mcmcs[model] = {}
        for itry in range(num_tries):
            t0 = time.time()
            mcmcs[model][dataname] = models[model].sampling(data=data[dataname], iter=2000, chains=num_chains)
            sampling_time[model][dataname].append(time.time() - t0) # in seconds
            # get max Rhat
            rhat_max = get_max_rhat(mcmcs[model][dataname])
            maxrhats[model][dataname].append(rhat_max)
            print('{}: in try {}/{} found Rhat={:.3f}'.format(model, itry+1, num_tries, rhat_max), end='')
            if rhat_max < 1.1 or itry == num_tries - 1:
                print()
                break
            print(', trying again')
        
        print('{} ({})'.format(model, desc_model[model])) 
        print('\n'.join(x for x in mcmcs[model][dataname].__str__().split('\n') if '[' not in x or 'rho_max' in x or 'delta_max' in x or 'gamma_max' in x or 'E_star' in x or 'daily' in x))
        print()
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m12u NOW.
# m12u: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpqtafnjbq/stanfit4m12u_7532178934026417001.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# WARNING:pystan:n_eff / iter for parameter delta_incr[3] is 0.0006343714608687638!
# WARNING:pystan:n_eff / iter for parameter delta_incr[4] is 0.0007279158849663957!
# WARNING:pystan:n_eff / iter for parameter delta_incr[10] is 0.0006769464915478585!
# WARNING:pystan:n_eff / iter for parameter delta_incr[14] is 0.0008341564452718647!
# WARNING:pystan:n_eff / iter for parameter delta_incr[16] is 0.0009340363901470195!
# WARNING:pystan:n_eff / iter for parameter delta_incr[17] is 0.0007344641131296286!
# WARNING:pystan:n_eff / iter for parameter delta_max[1] is 0.0009985271821932923!
# WARNING:pystan:n_eff / iter for parameter delta_max[2] is 0.0008757443925614645!
# WARNING:pystan:n_eff / iter for parameter gamma_max[4] is 0.0005741405286128773!
# WARNING:pystan:n_eff / iter for parameter E_star_mu is 0.0006203563609756279!
# WARNING:pystan:n_eff / iter for parameter E_star[1] is 0.000648218230185364!
# WARNING:pystan:n_eff / iter for parameter E_star[2] is 0.0006640941720865398!
# WARNING:pystan:n_eff / iter for parameter E_star[4] is 0.000602342678420416!
# WARNING:pystan:n_eff / iter for parameter sigma is 0.0005030316401024932!
# WARNING:pystan:n_eff / iter for parameter exponent_gamma is 0.0005119004840522038!
# WARNING:pystan:n_eff / iter for parameter w_ini[3] is 0.0007430910254930532!
# WARNING:pystan:n_eff / iter for parameter w_ini[5] is 0.0005580347395115413!
# WARNING:pystan:n_eff / iter for parameter w_ini[6] is 0.0006769995111958124!
# WARNING:pystan:n_eff / iter for parameter w_ini[7] is 0.0005650841195267042!
# WARNING:pystan:n_eff / iter for parameter w_ini[8] is 0.0005825204855759946!
# WARNING:pystan:n_eff / iter for parameter w_ini[9] is 0.0006001361767123796!
# WARNING:pystan:n_eff / iter for parameter w_ini[11] is 0.0008397416421718154!
# WARNING:pystan:n_eff / iter for parameter w_ini[13] is 0.0009587891185665106!
# WARNING:pystan:n_eff / iter for parameter w_ini[14] is 0.0006317524728923548!
# WARNING:pystan:n_eff / iter for parameter w_ini[15] is 0.0006565015470927673!
# WARNING:pystan:n_eff / iter for parameter w_ini[16] is 0.0007422901597883276!
# WARNING:pystan:n_eff / iter for parameter w_ini[18] is 0.0007895378084047969!
# WARNING:pystan:n_eff / iter for parameter w_ini[19] is 0.0006125006690572138!
# WARNING:pystan:n_eff / iter for parameter w_ini[21] is 0.0009844085477232886!
# WARNING:pystan:n_eff / iter for parameter w_ini[22] is 0.0005791476876886204!
# WARNING:pystan:n_eff / iter for parameter w_ini[25] is 0.0005989491453487402!
# WARNING:pystan:n_eff / iter for parameter divrate_daily[1] is 0.0006897504718287107!
# WARNING:pystan:n_eff / iter for parameter divrate_daily[4] is 0.0005623957780621504!
# WARNING:pystan:n_eff / iter for parameter delta[3] is 0.0005742236438727452!
# WARNING:pystan:n_eff / iter for parameter delta[4] is 0.000540627844213712!
# WARNING:pystan:n_eff / iter for parameter delta[5] is 0.000558661485702073!
# WARNING:pystan:n_eff / iter for parameter delta[6] is 0.0005684897717408863!
# WARNING:pystan:n_eff / iter for parameter delta[7] is 0.0005840216155452544!
# WARNING:pystan:n_eff / iter for parameter delta[8] is 0.0006306875587833621!
# WARNING:pystan:n_eff / iter for parameter delta[9] is 0.0006151150236091539!
# WARNING:pystan:n_eff / iter for parameter delta[10] is 0.0005550989083604044!
# WARNING:pystan:n_eff / iter for parameter delta[11] is 0.0005808679681820685!
# WARNING:pystan:n_eff / iter for parameter delta[12] is 0.0006632576473360579!
# WARNING:pystan:n_eff / iter for parameter delta[14] is 0.0008224457306473177!
# WARNING:pystan:n_eff / iter for parameter delta[15] is 0.0007222520984688185!
# WARNING:pystan:n_eff / iter for parameter delta[16] is 0.0007344641131296694!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,1] is 0.0007430910254930532!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,1] is 0.0005580347395115413!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,1] is 0.0006769995111958124!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,1] is 0.0005650841195267042!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,1] is 0.0005825204855759946!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,1] is 0.0006001361767123796!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,1] is 0.0008397416421718154!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,1] is 0.0009587891185665106!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,1] is 0.0006317524728923548!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,1] is 0.0006565015470927673!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,1] is 0.0007422901597883276!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,1] is 0.0007895378084047969!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,1] is 0.0006125006690572138!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,1] is 0.0009844085477232886!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,1] is 0.0005791476876886204!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,1] is 0.0005989491453487402!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,2] is 0.0009877148600600173!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,2] is 0.0007786671123563239!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,2] is 0.0006517513837677562!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,2] is 0.0007356208942151445!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,2] is 0.0005626383851681!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,2] is 0.0005543878813907884!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,2] is 0.0005848525356506989!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,2] is 0.0006319395913637584!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,2] is 0.0006619966336659504!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,2] is 0.0007549324588349863!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,2] is 0.0009762953365211274!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,3] is 0.0006807410912123339!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,3] is 0.0006184749618601065!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,3] is 0.000692851313502494!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,3] is 0.000771358624980267!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,3] is 0.0007160971290003442!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,3] is 0.0007270021776672145!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,3] is 0.0006756223719795282!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,3] is 0.000678033235377663!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,3] is 0.0008162166291555923!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,3] is 0.0009439694222294697!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,3] is 0.0008871568571610613!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,3] is 0.0008946182400718058!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,4] is 0.0006419545799185764!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,4] is 0.0005586496487232227!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,4] is 0.0005562738715188098!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,4] is 0.0005823061342093123!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,4] is 0.0006130641065181079!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,4] is 0.0006267656564662685!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,4] is 0.0006470813769620842!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,4] is 0.0007237479692537281!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,4] is 0.0008917603034243163!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,5] is 0.000644070359628316!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,5] is 0.0005535303914527459!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,5] is 0.0005443401257069124!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,5] is 0.000553477835409854!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,5] is 0.0005818645969200323!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,5] is 0.000610787840638284!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,5] is 0.0006774215201621305!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,5] is 0.0007874568440648703!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,5] is 0.0009455927854733508!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,5] is 0.0009353265889783868!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,6] is 0.0006424323151018439!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,6] is 0.0005514462581578251!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,6] is 0.0005486648110532311!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,6] is 0.0005626164941414561!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,6] is 0.0005851874053505866!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,6] is 0.0006230882031334006!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,6] is 0.0007089213201711895!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,6] is 0.0008538227458840253!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,6] is 0.0007244691292850014!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,6] is 0.0006510297211725527!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,6] is 0.0006805235027149093!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,6] is 0.0007065097680603513!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,6] is 0.0008130338889943422!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,7] is 0.0006429491438762082!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,7] is 0.00054921752402501!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,7] is 0.0005484918475662775!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,7] is 0.0005672485113141929!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,7] is 0.0005961330372131351!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,7] is 0.0006388084114061564!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,7] is 0.0007241638829275428!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,7] is 0.0008817015927860344!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,7] is 0.000951326823733807!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,7] is 0.0006488717187931467!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,7] is 0.0005901549421165218!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,7] is 0.0005874460792574015!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,7] is 0.0005872626905992901!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,7] is 0.0006132613450159474!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,7] is 0.0007590698283063776!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,8] is 0.0006400110811400536!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,8] is 0.0005502253093268567!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,8] is 0.0005499022657574339!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,8] is 0.0005707584535085855!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,8] is 0.0006008953004101016!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,8] is 0.0006443238016665258!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,8] is 0.0007258014152278443!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,8] is 0.0008720620463765826!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,8] is 0.0007836679615658076!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,8] is 0.0006053067292828415!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,8] is 0.000562591620618008!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,8] is 0.00055438695757922!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,8] is 0.0005500685581061299!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,8] is 0.0005594390318868967!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,8] is 0.0006187063838016907!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,9] is 0.0006286994336621259!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,9] is 0.0005561066759707382!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,9] is 0.0005567640141312346!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,9] is 0.0005771583515673191!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,9] is 0.0006070868037258425!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,9] is 0.000649501772410065!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,9] is 0.0007247443576290292!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,9] is 0.0008571464126420954!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,9] is 0.0006934140646465221!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,9] is 0.0005754393425494098!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,9] is 0.0005448655894658701!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,9] is 0.0005371052741383097!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,9] is 0.0005329858815147223!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,9] is 0.0005372100015559093!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,9] is 0.0005684580272801442!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,9] is 0.0007922179388566475!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,10] is 0.0006084882318356526!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,10] is 0.0005570775646604816!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,10] is 0.0005664312690229396!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,10] is 0.0005883054738457459!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,10] is 0.0006176219178259727!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,10] is 0.0006579342911578424!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,10] is 0.0007281271380610509!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,10] is 0.0008488848611852822!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,10] is 0.000648865156141084!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,10] is 0.0005570032715594257!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,10] is 0.000533314773276836!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,10] is 0.0005267213660982617!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,10] is 0.0005235337003053168!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,10] is 0.0005259623448358989!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,10] is 0.000545434141804392!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,10] is 0.0006712507633071282!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,11] is 0.0005936697506703877!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,11] is 0.0005562212218886783!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,11] is 0.000572808917310042!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,11] is 0.0005977355522788934!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,11] is 0.0006296738974395403!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,11] is 0.0006707146080706198!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,11] is 0.0007368611520016748!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,11] is 0.000848359988146328!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,11] is 0.0006272651628551345!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,11] is 0.0005466159836136547!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,11] is 0.0005262016077134007!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,11] is 0.0005203081056579841!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,11] is 0.0005178249761736601!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,11] is 0.0005195841917537508!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,11] is 0.0005331647782570128!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,11] is 0.000614083692777474!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,12] is 0.0005837674092517223!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,12] is 0.0005604957972669948!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,12] is 0.0005804772254843326!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,12] is 0.0006069253812115671!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,12] is 0.0006407510569059914!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,12] is 0.0006842539821525557!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,12] is 0.0007523120630930372!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,12] is 0.0008665558540743377!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,12] is 0.0005934120131620073!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,12] is 0.0005351066699577339!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,12] is 0.0005198678941561649!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,12] is 0.0005152905730514008!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,12] is 0.0005134439912715468!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,12] is 0.0005149541227501447!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,12] is 0.0005248105625782225!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,12] is 0.0005791004838038496!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,13] is 0.0005722977192006449!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,13] is 0.0005703582619237441!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,13] is 0.0005928048940934787!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,13] is 0.0006206991533387477!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,13] is 0.0006580097397051449!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,13] is 0.000707103861026496!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,13] is 0.0007872755543348397!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,13] is 0.000942247440548522!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,13] is 0.0006533314653298784!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,13] is 0.0005397138582970159!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,13] is 0.0005186969706707289!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,13] is 0.0005124544865981428!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,13] is 0.0005105476296472733!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,13] is 0.000509676760943213!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,13] is 0.0005113683112072861!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,13] is 0.000520178575214894!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,13] is 0.0005610520628211429!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,14] is 0.0005724824209063748!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,14] is 0.0005856944501962566!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,14] is 0.0006110987256276671!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,14] is 0.000643380319033203!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,14] is 0.0006905647850706473!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,14] is 0.0007550909736497987!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,14] is 0.0008801059249184554!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,14] is 0.0006873850814530667!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,14] is 0.0005362049605615811!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,14] is 0.0005160016226060864!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,14] is 0.0005118572961633473!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,14] is 0.0005106808523822511!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,14] is 0.0005108829760617505!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,14] is 0.0005113657352558884!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,14] is 0.0005185774437838409!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,14] is 0.0005520780841461757!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,14] is 0.0006749362810130753!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,15] is 0.0009638514765796437!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,15] is 0.0005863231719358493!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,15] is 0.0006042898790534605!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,15] is 0.0006361042669261375!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,15] is 0.0006799212956341963!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,15] is 0.0007498569528720417!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,15] is 0.00084846545992661!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,15] is 0.0005344759184720395!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,15] is 0.0005138995667664008!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,15] is 0.0005090363734950285!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,15] is 0.0005086575447738299!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,15] is 0.000508771502578479!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,15] is 0.000509786424685742!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,15] is 0.0005117567460646399!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,15] is 0.0005291003919806073!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,15] is 0.0006367136196071155!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,16] is 0.0008482014446678624!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,16] is 0.0005995593944542011!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,16] is 0.0006234663456279537!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,16] is 0.0006654055363381165!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,16] is 0.0007280346678625508!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,16] is 0.0008342904238438561!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,16] is 0.00099167783022988!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,16] is 0.0006430220958416344!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,16] is 0.0005129495449496316!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,16] is 0.0005077774197772769!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,16] is 0.0005061424640518037!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,16] is 0.000506602692872822!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,16] is 0.0005071872184768535!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,16] is 0.000509032063130514!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,16] is 0.000513362996195953!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,16] is 0.0005532198873454638!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,16] is 0.0009306340272484536!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,17] is 0.0007728135921669305!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,17] is 0.0006134275536305929!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,17] is 0.0006449828966105498!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,17] is 0.0007012498571436535!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,17] is 0.0007909232256582332!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,17] is 0.0009520153742167397!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,17] is 0.0005575143291829979!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,17] is 0.0005070428213731191!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,17] is 0.0005053532399417713!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,17] is 0.000504824504292866!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,17] is 0.0005055770090432672!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,17] is 0.0005066871909065016!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,17] is 0.0005099927479050305!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,17] is 0.0005179934824858997!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,17] is 0.0005954701399892389!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,18] is 0.0007333755966224622!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,18] is 0.0006292843427845867!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,18] is 0.0006700516301695018!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,18] is 0.0007460122251000998!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,18] is 0.0008739941950249974!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,18] is 0.0005311256858124748!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,18] is 0.0005048082051922596!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,18] is 0.0005041954506458201!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,18] is 0.0005041691748323167!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,18] is 0.0005051847068359608!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,18] is 0.0005071087061097019!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,18] is 0.0005125978169482584!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,18] is 0.0005256206393790682!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,18] is 0.0006567907715491005!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,19] is 0.0007112478979893656!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,19] is 0.0006476008181109507!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,19] is 0.0006997063652786425!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,19] is 0.0008022838366900045!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,19] is 0.0009841206050802615!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,19] is 0.0005195160220759719!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,19] is 0.0005037759165094417!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,19] is 0.0005035769428479826!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,19] is 0.0005039260070638632!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,19] is 0.0005053216915302053!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,19] is 0.0005083366644544755!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,19] is 0.0005167722255275053!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,19] is 0.0005360351166008683!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,19] is 0.0007384739709540973!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,20] is 0.0006959292866847617!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,20] is 0.0006686658043007931!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,20] is 0.0007350397742483179!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,20] is 0.0008731896198056224!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,20] is 0.0005134298090228478!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,20] is 0.0005032394446175689!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,20] is 0.0005032590754246625!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,20] is 0.0005039943976260669!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,20] is 0.000505961473427111!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,20] is 0.0005103787372036714!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,20] is 0.0005224194786894646!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,20] is 0.0005493328405834035!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,20] is 0.0008413109220320709!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,21] is 0.0006855470490988479!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,21] is 0.0006928792533267273!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,21] is 0.0007773521397482394!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,21] is 0.0009628186248190011!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,21] is 0.0005098318341593346!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,21] is 0.0005029618124811958!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,21] is 0.0005031505092244476!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,21] is 0.0005043351878628715!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,21] is 0.0005070539685225802!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,21] is 0.0005131678836790509!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,21] is 0.0005295528910047223!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,21] is 0.0005654819599202591!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,21] is 0.000966715522852623!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,22] is 0.0006783150796710846!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,22] is 0.0007205982810083079!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,22] is 0.0008276749906475974!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,22] is 0.000507569721529173!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,22] is 0.0005028443508731321!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,22] is 0.0005032314589767202!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,22] is 0.0005049535059016488!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,22] is 0.0005085646903723531!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,22] is 0.0005166636763736984!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,22] is 0.0005381633618354699!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,22] is 0.0005845442062270681!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,23] is 0.0006730514915742057!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,23] is 0.0007519033111847611!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,23] is 0.0008867737793479827!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,23] is 0.0005060935083897708!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,23] is 0.000502847976905617!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,23] is 0.0005034739740968934!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,23] is 0.0005057935142580759!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,23] is 0.0005104005322091907!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,23] is 0.0005207070887789563!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,23] is 0.0005477560560615917!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,23] is 0.0006055809603384733!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,24] is 0.0007759093372966395!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,24] is 0.000722841369665229!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,24] is 0.0009010926851924861!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,24] is 0.000513805339207585!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,24] is 0.0005046774709145142!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,24] is 0.0005052339171958762!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,24] is 0.0005072299602837968!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,24] is 0.0005104282027350261!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,24] is 0.0005118450081533484!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,24] is 0.0005198054791560072!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,24] is 0.0005365392112485711!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,24] is 0.0005973897965845307!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,24] is 0.0007847306697491332!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,25] is 0.0008059445467412793!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,25] is 0.0006871711790251806!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,25] is 0.0007700634311014838!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,25] is 0.0006284646501438917!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,25] is 0.0005169828395976439!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,25] is 0.0005104902260302409!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,25] is 0.0005113603028447598!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,25] is 0.0005153009354533645!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,25] is 0.0005190311064252018!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,25] is 0.0005205686585342048!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,25] is 0.0005242311161998081!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,25] is 0.000536920587224349!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,25] is 0.0005684964735714624!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,25] is 0.0006397288190465582!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,25] is 0.0008423670928688153!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,26] is 0.0009499094519891418!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,26] is 0.0008031878315576375!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,26] is 0.0008844939808545751!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,26] is 0.0006024003991402137!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,26] is 0.0005171269795285891!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,26] is 0.0005121136098570575!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,26] is 0.0005139677742974824!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,26] is 0.0005168215721755465!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,26] is 0.0005192904438640637!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,26] is 0.0005216901387376092!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,26] is 0.0005270678286437349!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,26] is 0.0005402517111941976!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,26] is 0.0005894142443025695!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,26] is 0.0008136845797879498!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,27] is 0.000556030041096105!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,27] is 0.0005168661406525387!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[18,27] is 0.0005153163741040552!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,27] is 0.000517316725049073!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,27] is 0.0005210215817329985!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,27] is 0.0005286172216124514!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,27] is 0.0005705425469100375!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,27] is 0.0007654218253151574!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[19,28] is 0.0005504604025429297!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,28] is 0.000524104694563346!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,28] is 0.0005282973826256217!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,28] is 0.0005699259178914025!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,28] is 0.0007668058198244267!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,30] is 0.0009330633746228325!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,30] is 0.0008451194947064956!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,30] is 0.0008220077962693957!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,30] is 0.0008149047956172638!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,31] is 0.0009140447026265758!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,31] is 0.0008488456968403172!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,31] is 0.0008162067127282899!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,31] is 0.0008090045651776213!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,31] is 0.0008071708500350629!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,32] is 0.0009745434484830963!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,32] is 0.0008899323637520201!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,32] is 0.000835484483386866!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,32] is 0.0008120961713439607!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,32] is 0.00080763226449058!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,32] is 0.0008066860551968501!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,33] is 0.0009759834543682975!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,33] is 0.0008865056412601831!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,33] is 0.0008324838731696455!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,33] is 0.0008110867116519966!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,33] is 0.0008073179809023614!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,33] is 0.0008065957373483198!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,34] is 0.0009807274211863165!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,34] is 0.0008890017412189235!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,34] is 0.0008326965805316168!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,34] is 0.0008109348139639289!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,34] is 0.0008072409670416773!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,34] is 0.0008065690633080344!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,35] is 0.0009784379515906604!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,35] is 0.0008910936361883158!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,35] is 0.0008338531823681685!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,35] is 0.0008111338067261243!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,35] is 0.0008072599654815396!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,35] is 0.0008065620180841336!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,36] is 0.0009990084094719496!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,36] is 0.0009030805485514932!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,36] is 0.0008381844924149646!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,36] is 0.0008119676488659032!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,36] is 0.0008074226291690186!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,36] is 0.0008065769800169179!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,37] is 0.0008364174072102384!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,37] is 0.0008993585962228944!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,37] is 0.0009956301996574659!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,37] is 0.0009643100892626819!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,37] is 0.0008555107653861171!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,37] is 0.000814884628147609!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,37] is 0.000808005277466302!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,37] is 0.0008066525183505147!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,38] is 0.0007803420618493796!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,38] is 0.0008093560598026248!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,38] is 0.0009000115349374219!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,38] is 0.0008915766335467615!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,38] is 0.0008200753371914975!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,38] is 0.0008082186525960384!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,38] is 0.0008067867322601961!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,38] is 0.0008065272595349516!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,39] is 0.0007783613919160845!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,39] is 0.0008396585963584418!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,39] is 0.0009420846519627438!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,39] is 0.0009441952277305382!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,39] is 0.0008240502694379281!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,39] is 0.0008068580585831634!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,39] is 0.0008065262570646684!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,39] is 0.0008064978139591454!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,39] is 0.0008064930122292648!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,40] is 0.0008026335900278392!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,40] is 0.0008715016186166462!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,40] is 0.0009808139695142192!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,40] is 0.0008820315850857942!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,40] is 0.0008110866950854258!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,40] is 0.0008065074604727642!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,40] is 0.0008064931528698618!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,40] is 0.0008064924054281424!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,40] is 0.0008064923569837156!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,41] is 0.0008301520807576434!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,41] is 0.0009004587577287069!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,41] is 0.0008507378150937487!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,41] is 0.0008078527638114186!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,41] is 0.0008064929535405937!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,41] is 0.0008064923014084746!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,41] is 0.0008064923222696055!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,41] is 0.0008064923622154686!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,42] is 0.0008868643774594674!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,42] is 0.0008559690301303203!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,42] is 0.0009268086763090071!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,42] is 0.0008334252627483588!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,42] is 0.0008069357038611701!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,42] is 0.0008064922685133668!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,42] is 0.0008064923256689336!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,42] is 0.0008064923492636188!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,42] is 0.0008064923720897856!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,43] is 0.0008352875370114717!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,43] is 0.000879507693849283!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,43] is 0.000951282329696426!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,43] is 0.0008233257384758653!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,43] is 0.0008066489227689481!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,43] is 0.000806492288503434!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,43] is 0.000806492352943414!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,43] is 0.0008064923647282253!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,43] is 0.0008064923769290845!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,44] is 0.0008201817529504941!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,44] is 0.0009010220122522343!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,44] is 0.000974498487732462!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,44] is 0.000817227746982833!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,44] is 0.0008065515300976192!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,44] is 0.0008064923264891237!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,44] is 0.0008064923672972842!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,44] is 0.0008064923729770296!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,44] is 0.0008064923795149159!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,45] is 0.0008220568115610525!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,45] is 0.0009208949195146915!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,45] is 0.0009969863597281317!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,45] is 0.0008134529826689252!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,45] is 0.0008065160334336601!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,45] is 0.0008064923502322356!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,45] is 0.0008064923748352689!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,45] is 0.0008064923775520891!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,45] is 0.0008064923810328851!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,46] is 0.0008317497072458074!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,46] is 0.0009394863741327866!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,46] is 0.000811070297939084!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,46] is 0.0008065022948121121!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,46] is 0.0008064923641376958!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,46] is 0.0008064923788720515!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,46] is 0.0008064923801477391!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,46] is 0.0008064923819707889!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,47] is 0.0008314128157826627!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,47] is 0.0009505568300616733!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,47] is 0.000857883019490425!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[21,47] is 0.0008093439265896514!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,47] is 0.0008065154906641093!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,47] is 0.0008064923913669534!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[24,47] is 0.000806492381648673!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,47] is 0.0008064923825669935!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,48] is 0.0006423886523739099!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,48] is 0.0009151444575784414!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[22,48] is 0.0008770819166365133!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,48] is 0.0008081081763984863!
# ...
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[122] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[123] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[124] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[125] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[126] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[127] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[128] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[129] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[130] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[131] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[132] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[133] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[134] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[135] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[136] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[184] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[185] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[186] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[187] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[188] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[189] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[190] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[191] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[192] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[193] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[194] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[195] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[196] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[197] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[198] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[199] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[200] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[201] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[202] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[203] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[204] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[205] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[206] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[207] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[208] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[256] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[257] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[258] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[259] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[260] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[261] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[262] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[263] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[264] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[265] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[266] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[267] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[268] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[269] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[270] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[271] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[272] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[273] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[274] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[275] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[276] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[277] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[278] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[279] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[280] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[281] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[282] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[283] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[284] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[285] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[286] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[287] is nan!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[288] is nan!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter growth_size_gain[43] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[44] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[45] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[46] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[47] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[48] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[49] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[50] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[51] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[52] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[53] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[54] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[55] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[56] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[57] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[58] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[59] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[60] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[61] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[62] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[63] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[64] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[112] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[113] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[114] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[115] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[116] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[117] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[118] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[119] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[120] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[121] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[122] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[123] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[124] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[125] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[126] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[127] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[128] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[129] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[130] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[131] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[132] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[133] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[134] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[135] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[136] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[184] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[185] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[186] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[187] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[188] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[189] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[190] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[191] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[192] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[193] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[194] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[195] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[196] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[197] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[198] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[199] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[200] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[201] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[202] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[203] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[204] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[205] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[206] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[207] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[208] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[256] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[257] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[258] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[259] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[260] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[261] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[262] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[263] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[264] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[265] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[266] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[267] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[268] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[269] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[270] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[271] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[272] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[273] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[274] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[275] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[276] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[277] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[278] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[279] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[280] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[281] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[282] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[283] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[284] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[285] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[286] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[287] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[288] is nan!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:5520 of 6000 iterations ended with a divergence (92.0%).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:117 of 6000 iterations saturated the maximum tree depth of 10 (1.95%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# m12u: in try 2/3 found Rhat=1.039
# m12u (m$_{pmb}$)
# Inference for Stan model: m12u.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max_mu          182.38   10.14 201.14   58.4   77.9  114.7 202.27 737.01    394   1.01
# delta_max_sigma        25.41    0.76  15.29   6.32  14.21  22.07  33.21  63.14    401   1.01
# delta_max[1]           70.57    0.06   1.46  66.62   70.0  71.04  71.63  71.97    515   1.01
# delta_max[2]           60.18    0.25   3.63   53.4  57.73  60.11   62.4  67.83    205   1.02
# delta_max[3]           54.06     0.2   3.14  48.01  51.87  53.99  56.26  60.41    239   1.01
# delta_max[4]           67.38    0.16   2.83  61.38  65.37  67.67  69.65  71.69    297   1.02
# gamma_max_mu             4.2    0.08   1.57   0.52   3.32    4.5    5.4   6.39    432   1.01
# gamma_max_sigma         8.74    0.47   9.64    0.9   2.15   5.16  11.72  34.44    414   1.02
# gamma_max[1]            3.71    0.01    0.2   3.32   3.57   3.71   3.84   4.08    205   1.02
# gamma_max[2]            3.66    0.01    0.2   3.28   3.53   3.67    3.8   4.05    225   1.03
# gamma_max[3]            4.17    0.01   0.22   3.74   4.01   4.17   4.32   4.58    244   1.04
# gamma_max[4]            6.06    0.02   0.27   5.47   5.87   6.09   6.28   6.48    225   1.02
# rho_max_mu            3.8e-3  2.0e-4 4.9e-3 9.2e-5 1.0e-3 2.4e-3 4.9e-3   0.02    585   1.01
# rho_max_sigma         7.1e-3  3.9e-4   0.01 2.7e-4 1.8e-3 4.2e-3 8.4e-3   0.03    665   1.01
# rho_max[1]            3.3e-3  1.3e-4 3.0e-3 1.3e-4 1.1e-3 2.4e-3 4.6e-3   0.01    563   1.01
# rho_max[2]            4.0e-3  1.6e-4 3.6e-3 1.2e-4 1.3e-3 3.0e-3 5.7e-3   0.01    529   1.01
# rho_max[3]            3.0e-3  1.2e-4 2.8e-3 9.4e-5 9.4e-4 2.2e-3 4.2e-3   0.01    591   1.01
# rho_max[4]            6.7e-3  3.4e-4 7.1e-3 1.4e-4 1.7e-3 4.4e-3 9.2e-3   0.03    440   1.01
# E_star_mu              94.41    4.69 101.46   3.56  33.46   67.4 119.18 352.52    467   1.01
# E_star_sigma          224.57    9.53 186.67  63.27  118.9 174.37 261.73 709.89    384   1.01
# E_star[1]             264.44    3.86  68.43 144.42  216.2 261.14 306.53 411.58    314   1.01
# E_star[2]              36.89    1.23  24.41  10.36  18.74  29.22  48.82 100.69    396   1.02
# E_star[3]              26.95    0.94  19.32   7.77  14.86  20.93  32.04  82.53    420   1.01
# E_star[4]              28.29    0.71  16.61   9.38  16.66  23.63   35.6   72.4    549   1.01
# sigma                 774.79    0.98  22.59 730.01 759.82 774.98 790.35 818.93    530   1.01
# exponent_gamma          0.58  2.2e-3   0.03   0.51   0.55   0.58    0.6   0.63    212   1.03
# divrate                  1.2  9.9e-4   0.02   1.15   1.18    1.2   1.21   1.24    505   1.01
# divrate_daily[1]        0.97  2.0e-3   0.03   0.91   0.94   0.97   0.99   1.04    268   1.01
# divrate_daily[2]        0.97  2.2e-3   0.04    0.9   0.94   0.97   0.99   1.05    308   1.02
# divrate_daily[3]        1.16  2.2e-3   0.05   1.08   1.13   1.16    1.2   1.25    443   1.01
# divrate_daily[4]        1.72  2.3e-3   0.05   1.62   1.69   1.72   1.75   1.82    492   1.01
# lp__                  -4.4e6     1.4  35.54 -4.4e6 -4.4e6 -4.4e6 -4.4e6 -4.4e6    649   1.01
#
# Samples were drawn using NUTS at Mon Dec  7 19:10:51 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# ## plot the results

# %%
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['legend.fontsize'] = 16
mpl.rcParams['axes.titlesize'] = 26
mpl.rcParams['figure.figsize'] = (24,12)
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16

# set the color for each model
num_model = len(mcmcs)
if num_model <= 10:
    colors_model = {model:'C{}'.format(imodel) for imodel,model in enumerate(mcmcs)}
else:
    colors_model = {model:mpl.cm.viridis(imodel/(num_model-1)) for imodel,model in enumerate(mcmcs)}
    
maxrhats_final = {model:{dataname:get_max_rhat(mcmcs[model][dataname]) for dataname in data} for model in mcmcs}

# %%
param_desc = {'divrate':'daily division rate','E_star':'E*'}
# add known values here
reference_values = {'zinser':{'divrate':0.69}}

# %%
ylim_top = 0
for dataname in data:
    for model in mcmcs:
        ylim_top = max(ylim_top, len(maxrhats[model][dataname]))
ylim_top += 1

fig, axs = plt.subplots(nrows=len(data), figsize=(max(24,len(mcmcs)*4.5),len(data)*9), squeeze=False, sharex=True, sharey=True)
for ax,dataname in zip(axs.flat,data):
    xticks = []
    xticklabels = []
    for i,model in enumerate(mcmcs):
        
        height_bad = sum(rh > 1.1 for rh in maxrhats[model][dataname])
        height_good = len(maxrhats[model][dataname]) - height_bad
        
        x = i
        ax.bar(x=x, height=height_bad, color='tab:red', label='max $\\\\hat{R}$ > 1.1')
        ax.bar(x=x, height=height_good, bottom=height_bad, color='tab:green', label='max $\\hat{R} \le$ 1.1')
        
        if len(sampling_time[model][dataname]) != height_bad+height_good:
            print('{}, {}: Timing information inconsistent.'.format(dataname, desc_model[model]))
        else:
            for it, t in enumerate(sampling_time[model][dataname]):
                ax.text(x, it+0.5, '{:.0f}:{:02.0f}'.format(t//60, t%60), ha='center', va='center', size=30)
            
        xticks.append(x)
        xticklabels.append(desc_model[model].replace(',',',\n'))
    
    ax.set(ylabel='number of Stan sampling runs', xticks=xticks, ylim=(0, ylim_top))
    ax.set_title('convergence/$\hat{R}$ statistics for '+desc[dataname], size=20)
    ax.set_xticklabels(xticklabels)#, rotation=8)
    ax.grid(axis='y')

# %%
# updated code can handle all data[dataname]['i_test'] == 0 and draw only a single bar
if np.all(data[dataname]['i_test'] == 0):
    num_bars = 1
else:
    num_bars = 3

height = np.zeros(num_bars)
for dataname in data:
    obs = data[dataname]['obs']
    
    fig, ax = plt.subplots(figsize=(max(24,len(mcmcs)*4.5),9))
    xticks = []
    xticklabels = []
    for i,model in enumerate(mcmcs):
        mod_mean = np.mean(mcmcs[model][dataname]['mod_obspos'], axis=0)
        mod_mean /= np.sum(mod_mean, axis=0)
        
        e = np.sum((mod_mean-obs)**2,axis=0)
        #print(desc_model[model],e)
        
        height[0] = np.mean(e)
        if num_bars > 1:
            height[1] = np.mean(e[data[dataname]['i_test'] == 0])
            height[2] = np.mean(e[data[dataname]['i_test'] == 1])
        
        x = (num_bars+1)*i+np.arange(num_bars)
        ax.bar(x=x, height=height, color=colors_model[model])
        for xx,text in zip(x,['overall mean','training mean','test mean']):
            ax.text(xx, 0, '  '+text, rotation=90, ha='center', va='bottom', size=20)
        if maxrhats_final[model][dataname] > 1.1:
            ax.text(x[num_bars//3], 0, '  no convergence ($\\hat{R}>1.1$)', rotation=45, ha='center', va='bottom', size=30, color='darkred')
        xticks.append(x[num_bars//3])
        xticklabels.append(desc_model[model].replace(',',',\n').replace('(','\n('))
    
    if ax.get_ylim()[1] > 0.005:
        ax.set_ylim(top=0.005)
    ax.set(ylabel='sum of squared column differences', xticks=xticks)
    ax.set_title('model misfit for '+desc[dataname], size=20)
    ax.set_xticklabels(xticklabels)#, rotation=8)
    ax.grid(axis='y')

# %%
if 'size_units' not in globals():
    size_units = 'fg C cell$^{-1}$'

prop_labels = {
    'growth':'cell growth ({} h$^{{-1}}$)'.format(size_units),
    'division':'division rate (h$^{-1}$)',
    'respiration':'respiration + exudation\n({} h$^{{-1}}$)'.format(size_units),
}

for dataname in data:
    
    t = data[dataname]['dt']*np.arange(data[dataname]['nt'])/60.0
    dt_h = data[dataname]['dt']/60.0
    
    for model in mcmcs:
        fig, axs = plt.subplots(nrows=3, figsize=(14,6*3), sharex=True)

        cell_count = mcmcs[model][dataname]['cell_count']
        
        for ax, prop in zip(axs, ('growth', 'division', 'respiration')):

            if prop == 'growth':
                plotprop = mcmcs[model][dataname]['growth_size_gain']/cell_count/dt_h
                x = t
            elif prop == 'division':
                plotprop = (np.log(cell_count[:,1:])-np.log(cell_count[:,:-1]))/(t[1:]-t[:-1])
                x = 0.5 * (t[1:] + t[:-1])
            elif prop == 'respiration':
                plotprop = mcmcs[model][dataname]['resp_size_loss']/cell_count/dt_h
                x = t
            else:
                raise ValueError('Unknown prop "{}".'.format(prop))
            
            qq = np.percentile(plotprop, q=(5,25,50,75,95), axis=0)

            sc = ax.fill_between(x, qq[0,:], qq[-1,:], alpha=0.25, color=colors_model[model])
            ax.fill_between(x, qq[1,:], qq[-2,:], alpha=0.5, facecolor=sc.get_facecolor()[0])
            ax.plot(x, qq[2,:], color=sc.get_facecolor()[0][:-1], lw=2)

            if dataname == 'zinser':
                with nc4.Dataset('data/zinser_growthdivresp.nc') as nc:
                    ax.plot(nc[prop+'/time'][:], np.maximum(0.0, nc[prop+'/'+prop][:]), color='black', marker='o', lw=2)
            
            ax.set_ylim(bottom=0.0)
            ax.set_xlim((0, t[-1]))
            ax.set(ylabel=prop_labels[prop])
            ax.grid(True)
        
        axs[0].set_title(desc_model[model] + ' ' + desc[dataname])
        axs[-1].set(xticks = np.arange(0,t[-1],6), xlabel='time since start of experiment (h)')
        if axs[-1].get_ylim()[-1] < axs[0].get_ylim()[-1]:
            axs[-1].set_ylim(top=axs[0].get_ylim()[-1])

# %%
add_labels = True
for dataname in data:
    if 'zinser' in dataname:
        fig, ax = plt.subplots(figsize=(14,14))
        ax.set_title(desc[dataname], size=20)
        
        for model in mcmcs:
            # misfit to data

            obs = data[dataname]['obs']

            tmp = mcmcs[model][dataname]['mod_obspos']
            tmp/= np.sum(tmp, axis=1)[:,None,:]
            tmp -= obs[None,:,:]
            tmp **= 2
            
            if np.all(data[dataname]['i_test'] == 0):
                e0 = np.mean(np.sum(tmp, axis=1), axis=1)
                xlabel_suffix = ''
            else:
                e0 = np.mean(np.sum(tmp[:,:,data[dataname]['i_test'] == 1], axis=1), axis=1)
                xlabel_suffix = ' (test data)'
            
            # misfit to division rate

            e1 = np.abs(mcmcs[model][dataname]['divrate'] - reference_values[dataname]['divrate'])
        
            q0 = np.percentile(e0, q=(5,25,50,75,95))
            q1 = np.percentile(e1, q=(5,25,50,75,95))
            
            eb = ax.errorbar(x=q0[2], y=q1[2], xerr=np.array((q0[2]-q0[0], q0[-1]-q0[2]))[:,None], marker='o', ms=10, label=desc_model[model], color=colors_model[model])
            ax.errorbar(x=q0[2], y=q1[2], yerr=np.array((q1[2]-q1[0], q1[-1]-q1[2]))[:,None], color=eb[0].get_color())
            
            if add_labels:
                ax.text(q0[2], q1[2], ' '+desc_model[model], color=eb[0].get_color(), size=20)
            
            if maxrhats_final[model][dataname] > 1.1:
                ax.plot(q0[2], q1[2], marker='x', color='darkred', zorder=10, markersize=30, markeredgewidth=3)
        ax.grid(True)
        ax.legend()
        ax.set(xlabel='size distribution misfit'+xlabel_suffix, ylabel='daily division rate misfit')
        ax.set_xlim(left=0.0)
        ax.set_ylim(bottom=0.0)

# %%
datanames = tuple(data.keys())
if len(datanames) > 1:
    fig, ax = plt.subplots(figsize=(14,14))

    for model in mcmcs:
        qq = {}
        # misfit to data
        for dataname in datanames:
            obs = data[dataname]['obs']

            tmp = mcmcs[model][dataname]['mod_obspos']
            tmp/= np.sum(tmp, axis=1)[:,None,:]
            tmp -= obs[None,:,:]
            tmp **= 2

            if np.all(data[dataname]['i_test'] == 0):
                e0 = np.mean(np.sum(tmp, axis=1), axis=1)
            else:
                e0 = np.mean(np.sum(tmp[:,:,data[dataname]['i_test'] == 1], axis=1), axis=1)

            qq[dataname] = np.percentile(e0, q=(5,25,50,75,95))

        q0 = qq[datanames[0]]
        q1 = qq[datanames[1]]

        eb = ax.errorbar(x=q0[2], y=q1[2], xerr=np.array((q0[2]-q0[0], q0[-1]-q0[2]))[:,None], marker='o', ms=10, label=desc_model[model], color=colors_model[model])
        ax.errorbar(x=q0[2], y=q1[2], yerr=np.array((q1[2]-q1[0], q1[-1]-q1[2]))[:,None], color=eb[0].get_color())
        if maxrhats_final[model][dataname] > 1.1:
            ax.plot(q0[2], q1[2], marker='x', color='darkred', zorder=10, markersize=30, markeredgewidth=3)

    ax.grid(True)
    ax.legend()
    ax.set(xlabel='{} size distribution misfit'.format(desc[datanames[0]]), 
           ylabel='{} size distribution misfit'.format(desc[datanames[1]]))
    ax.set_xlim(left=0.0)
    ax.set_ylim(bottom=0.0)
None

# %%
data_fig2a = pd.read_csv('data/Zinser_Figure2A.csv')
t_zinser = data_fig2a['exper time'] * 60
ab_mean_norm = 0.5*(data_fig2a['cells A'].values/data_fig2a['cells A'].values[0] + 
                    data_fig2a['cells B'].values/data_fig2a['cells B'].values[0])

add_labels = True
for dataname in data:
    if 'zinser' in dataname:
        fig, ax = plt.subplots(figsize=(14,14))
        ax.set_title(desc[dataname], size=20)
        
        for model in mcmcs:
            # make sure the time is right, if not implement something fancier
            assert all(t_zinser.values[:-1] == data[dataname]['t_obs'])
            
            # misfit to normalized abundance
            
            e0 = np.mean(np.abs(np.sum(mcmcs[model][dataname]['mod_obspos'], axis=1)[:,1:]-ab_mean_norm[1:-1]), axis=1)
            
            # misfit to division rate

            e1 = np.abs(mcmcs[model][dataname]['divrate'] - reference_values[dataname]['divrate'])
        
            q0 = np.percentile(e0, q=(5,25,50,75,95))
            q1 = np.percentile(e1, q=(5,25,50,75,95))
            
            eb = ax.errorbar(x=q0[2], y=q1[2], xerr=np.array((q0[2]-q0[0], q0[-1]-q0[2]))[:,None], marker='o', ms=10, label=desc_model[model], color=colors_model[model])
            ax.errorbar(x=q0[2], y=q1[2], yerr=np.array((q1[2]-q1[0], q1[-1]-q1[2]))[:,None], color=eb[0].get_color())
            if add_labels:
                ax.text(q0[2], q1[2], ' '+desc_model[model], color=eb[0].get_color(), size=20)
            if maxrhats_final[model][dataname] > 1.1:
                ax.plot(q0[2], q1[2], marker='x', color='darkred', zorder=10, markersize=30, markeredgewidth=3)
        ax.grid(True)
        ax.legend()
        ax.set(xlabel='normalized abundance misfit (hourly division rate)', ylabel='daily division rate misfit')
        ax.set_xlim(left=0.0)
        ax.set_ylim(bottom=0.0)

# %%
for param in ('divrate', 'divrate_daily', 'delta_max', 'E_star', 'gamma_max', 'rho_max'):
    for dataname in data:
        num_mcmcs = len(mcmcs)
        for model in mcmcs:
            if mcmcs[model][dataname][param].ndim > 1:
                num_p = mcmcs[model][dataname][param].shape[1]
            else:
                num_p = 1
            fig, ax = plt.subplots(figsize=(24,2*num_p))
            if param in param_desc:
                ax.set_title('{} for {}'.format(param_desc[param], desc[dataname]))
            else:
                ax.set_title('{} for {}'.format(param, desc[dataname]))
            ax.violinplot(mcmcs[model][dataname][param], showmedians=True, vert=False)
            ax.invert_yaxis()
            ax.grid(axis='x')
            ax.set(yticks=np.arange(1,num_p+1), yticklabels=['day {}'.format(i+1) for i in range(num_p)])
        if dataname in reference_values and param in reference_values[dataname]:
            ax.axvline(reference_values[dataname][param], color='tab:green', lw=3)
        for i,model in enumerate(mcmcs):
            if maxrhats_final[model][dataname] > 1.1:
                ax.text(0.5, i+1, 'no convergence ($\\hat{R}>1.1$)', color='darkred', size=26, transform=ax.get_yaxis_transform(), ha='center', va='center')

# %%
for dataname in data:
    for model,mcmc in mcmcs.items():
        j = data_gridded[dataname]['delta_v_inv'] + 1
        m = data_gridded[dataname]['m']

        fig, ax = plt.subplots(figsize=(20,6))
        ax.set_title(desc_model[model] + '\n' + desc[dataname])
        ax.boxplot(mcmc[dataname]['delta'])
        xlabels = [str(x) for x in range(j,m+1)]
        xlabels[0] = 'j='+xlabels[0]
        xlabels[-1] = 'm='+xlabels[-1]
        ax.set_xticklabels(xlabels)
        ax.grid(axis='y')
        ax.set_ylabel('$\\delta_{max}$')
        
        if maxrhats_final[model][dataname] > 1.1:
            ax.text(0.5, 0.5, 'no convergence ($\\hat{R}>1.1$)', color='darkred', size=26, transform=ax.transAxes, ha='center', va='center')
        None

# %%
data_fig2a = pd.read_csv('data/Zinser_Figure2A.csv')

t_zinser = data_fig2a['exper time'] * 60
a_norm = data_fig2a['cells A'].copy()
a_norm /= a_norm[0]
b_norm = data_fig2a['cells B'].copy()
b_norm /= b_norm[0]

colors = {'model':'darkred', 'obs':'0.1'}

norm = mpl.colors.Normalize(0.0,0.15)
norm_diff = mpl.colors.Normalize(-0.1,0.1)

for dataname in data:
    t = data[dataname]['dt']*np.arange(data[dataname]['nt'])
    delta_v = 1.0/data_gridded[dataname]['delta_v_inv']
    v_ext = data[dataname]['v_min'] * 2**(np.arange(data[dataname]['m']+1)*delta_v) 
    v = v_ext[:-1]
    v_width = v_ext[1:] - v_ext[:-1]
        
    for model,mcmc in mcmcs.items():
        
        res = {'model':np.mean(mcmc[dataname]['mod_obspos'], axis=0), 'obs':data[dataname]['obs']}
        res_sum1 = res['model']/np.sum(res['model'], axis=0)[None,:]
        diff = res_sum1-res['obs']

        if maxrhats_final[model][dataname] > 1.1:
            fig, ax = plt.subplots(figsize=(24,4))
            ax.set_title(desc_model[model] + '\n' + desc[dataname])
            ax.set(xticks=[], yticks=[])
            ax.text(0.5, 0.5, 'no convergence ($\\hat{R}>1.1$)', color='darkred', size=26, transform=ax.transAxes, ha='center', va='center')
            continue
        
        fig,axs = plt.subplots(6,1,sharex=True,figsize=(24,40))
        axs[0].set_title(desc_model[model] + '\n' + desc[dataname])

        ax = axs[0]
        ax.plot(t, data[dataname]['E'], color='gold')
        ax.set(xlim=(data[dataname]['t_obs'][0],t[-1]), ylabel='PAR')

        ax = axs[1]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, res['obs'],norm=norm, shading='auto')
        ax.set(ylabel='size ({})'.format(size_units), title='size distribution data')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='size class proportion')

        ax = axs[2]
        ax.set(ylabel='size ({})'.format(size_units), title='size distribution model posterior')
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, res_sum1,norm=norm, shading='auto')

        ax = axs[3]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, diff,norm=norm_diff, cmap='PiYG', shading='auto')
        ax.set(ylabel='size ({})'.format(size_units), title='model - data misfit')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='difference in size class proportion')
        
        qq = np.percentile(np.sum(mcmc[dataname]['mod_obspos'], axis=1), axis=0, q=(5,25,50,75,95))
    
        ax = axs[4]
        ax.fill_between(data[dataname]['t_obs'], qq[0,:], qq[-1,:], alpha=0.25, color='gold')
        ax.fill_between(data[dataname]['t_obs'], qq[1,:], qq[-2,:], alpha=0.5, color='gold')
        ax.plot(data[dataname]['t_obs'], qq[2,:], color='gold')
        if 'zinser' in dataname:
            ax.plot(t_zinser, a_norm, color='black', marker='s', label='Zinser normalized "cells A"')
            ax.plot(t_zinser, b_norm, color='red', marker='^', label='Zinser normalized "cells B"')
            for iday in range(2):
                ax.axvspan(iday*24*60+12*60, iday*24*60+22*60, color='0.7', zorder=0)
            ax.legend()
        ax.grid(True)
        ax.set(ylabel='sum across size classes', title='relative increase in population size (division)')

        ax = axs[5]
        prop = np.mean(np.abs(diff),axis=0)
        ax.plot(data[dataname]['t_obs'], prop, label='mean(abs(diff)), avg: {:.6f}'.format(np.mean(prop)))
        prop = np.sum(diff**2,axis=0)
        ax.plot(data[dataname]['t_obs'], prop, label='sum(diff$^2$), avg: {:.6f}'.format(np.mean(prop)))
        ax.set(xlabel='time (minutes)', ylabel='model-observation misfit')
        ax.grid(True)
        ax.legend()

# %%
if 'varnames_save' not in globals():
    varnames_save = None

save_only_converged = True

if savename_output is not None:    
    with nc4.Dataset(savename_output, 'w') as nc:
        for dataname in data:
            ncg = nc.createGroup(dataname)

            if save_stan_output:
                dimensions = {
                    'obstime':int(data[dataname]['nt_obs']),
                    'time':int(data[dataname]['nt']),
                    'sizeclass':int(data[dataname]['m']),
                    'm_minus_j_plus_1':int(data[dataname]['m']-data[dataname]['delta_v_inv']),
                }
                dimensions_inv = {v:k for k,v in dimensions.items()}
                for d in dimensions:
                    ncg.createDimension(d, dimensions[d])
                    
                ncg.createVariable('time', int, ('time',))
                ncg.variables['time'][:] = int(data[dataname]['dt']) * np.arange(data[dataname]['nt'])
                ncg.variables['time'].units = 'minutes since start of experiment'
                
                ncg.createVariable('obstime', int, ('obstime',))
                ncg.variables['obstime'][:] = data[dataname]['t_obs'].astype(int)
                ncg.variables['obstime'].units = 'minutes since start of experiment'
                ncg.variables['obstime'].long_name = 'time of observations'

                for v in ('dt', 'm', 'v_min', 'delta_v_inv', 'obs', 'i_test', 'E', 'obs_count'):
                    if isinstance(data[dataname][v], int):
                        ncg.createVariable(v, int, zlib=True)
                        ncg.variables[v][:] = data[dataname][v]
                    elif isinstance(data[dataname][v], float):
                        ncg.createVariable(v, float, zlib=True)
                        ncg.variables[v][:] = data[dataname][v]
                    else:
                        dims = tuple(dimensions_inv[d] for d in data[dataname][v].shape)
                        ncg.createVariable(v, data[dataname][v].dtype, dims, zlib=True)
                        ncg.variables[v][:] = data[dataname][v]
                
                for imodel,model in enumerate(mcmcs):
                    if save_only_converged and get_max_rhat(mcmcs[model][dataname]) > 1.1:
                        logging.warning('Model "{}" did not converge -- skipping.'.format(model))
                        continue
                    ncm = ncg.createGroup(model)
                    
                    dimensions['sample'] = mcmcs[model][dataname]['mod_obspos'].shape[0]
                    dimensions_inv[dimensions['sample']] = 'sample'
                    ncm.createDimension('sample', dimensions['sample'])
                    if mcmcs[model][dataname]['E_star'].ndim == 2:
                        dimensions['day'] = mcmcs[model][dataname]['E_star'].shape[1]
                        dimensions_inv[dimensions['day']] = 'day'
                        ncm.createDimension('day', dimensions['day'])
                    if 'tau[1]' in mcmcs[model][dataname].flatnames:
                        dimensions['tau'] = mcmcs[model][dataname]['tau'].shape[1]
                        dimensions_inv[dimensions['tau']] = 'tau'
                        ncm.createDimension('tau', dimensions['tau'])
                    if 'tau_control[1]' in mcmcs[model][dataname].flatnames:
                        dimensions['tau_control'] = mcmcs[model][dataname]['tau_control'].shape[1]
                        dimensions_inv[dimensions['tau_control']] = 'tau_control'
                        ncm.createDimension('tau_control', dimensions['tau_control'])
                    
                    # write model description
                    ncm.setncattr('description', desc_model[model])
                    ncm.setncattr('code', stan_files[model_stan_key[model]])
                    
                    varnames = set(v.split('[')[0] for v in mcmcs[model][dataname].flatnames)
                    if varnames_save is None:
                        varnames_curr = varnames
                    else:
                        varnames_curr = varnames_save
                        
                    for v in varnames_curr:
                        if v in varnames:
                            try:
                                dims = tuple(dimensions_inv[d] for d in mcmcs[model][dataname][v].shape)
                            except:
                                for d in mcmcs[model][dataname][v].shape:
                                    if d not in dimensions_inv:
                                        logging.warning('Cannot find entry for "{}" in dimensions_inv.'.format(d))
                                logging.warning('Cannot save variable "{}" for model "{}".'.format(v, model))
                                continue
                            ncm.createVariable(v, float, dims, zlib=True)
                            ncm.variables[v][:] = mcmcs[model][dataname][v]
                        else:
                            logging.warning('Cannot find variable "{}" for model "{}".'.format(v, model))
            else:
                for i,model in enumerate(mcmcs):
                    if i == 0:
                        ncg.createDimension('model', len(mcmcs))
                        ncg.createDimension('sample', mcmcs[model][dataname]['divrate'].shape[0])

                        ncg.createVariable('divrate', float, ('model','sample'))
                        ncg.createVariable('sumsqdiff', float, ('model','sample'))
                        ncg.variables['sumsqdiff'].setncattr('long_name', 'sum of squared column differences')

                    ncg.variables['divrate'][i,:] = mcmcs[model][dataname]['divrate']

                    obs = data[dataname]['obs']

                    tmp = mcmcs[model][dataname]['mod_obspos']
                    tmp/= np.sum(tmp, axis=1)[:,None,:]
                    tmp -= obs[None,:,:]
                    tmp **= 2

                    if np.all(data[dataname]['i_test'] == 0):
                        ncg.variables['sumsqdiff'][i,:] = np.mean(np.sum(tmp, axis=1), axis=1)
                        if i == 0:
                            ncg.variables['sumsqdiff'].setncattr('data_used', 'all data')
                    else:
                        nc.variables['sumsqdiff'][i,:] = np.mean(np.sum(tmp[:,:,data[dataname]['i_test'] == 1], axis=1), axis=1)
                        if i == 0:
                            ncg.variables['sumsqdiff'].setncattr('data_used', 'testing data')

                    for iv,v in enumerate(('gamma_max','rho_max','xi','xir','E_star')):
                        if i == 0:
                            ncg.createVariable(v, float, ('model','sample'))
                        if v in mcmcs[model][dataname].flatnames:
                            ncg.variables[v][i,:] = mcmcs[model][dataname][v]
