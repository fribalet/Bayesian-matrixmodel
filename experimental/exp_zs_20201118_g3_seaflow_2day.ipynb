# %% [markdown]
# # fitting 2 days of SeaFlow data with new model formulations
#
# ### general information about the different growth/respiration versions
#
#  * for the functional form of the different size-dependent growth and respiration formulations see [this notebook](sizedep_formulations.ipynb)

# %% [markdown]
# ## global switches and settings

# %%
# use test data (not all data is used for fitting/training)
use_testdata = False

# create plots of the data
show_data = True

# netCDF output file (set to None to not save output)
savename_output = 'data_exp_zs_20201118_g3_seaflow_2day.nc'

# save the Stan output instead a few stats (only active if filename is specified above)
save_stan_output = True

# specify the Stan variable names to save; if set to None, all variables are saved 
# (only active if save_stan_output is True)
varnames_save = None

# the number of tries to fit each Stan model to achieve an R-hat < 1.1
num_tries = 3

# the number of chains to run
num_chains = 6

# the prior_only option passed to each Stan model
prior_only = False

# %% [markdown]
# ## load data from files and plot

# %%
#%matplotlib notebook
import netCDF4 as nc4
import numpy as np
import pandas as pd
import logging

# load data
datafiles = {
    'seaflow':'data/SeaFlow_PSD_hourlyCOUNT_v3_regrid-25-8_day3to4.nc',
    #'zinser':'data/Zinser_SizeDist_logtransform-25-7.nc',
}

itestfiles = {
    'seaflow':'data/Zinser_SizeDist_calibrated-26-6-itest.csv', # same as zinser
    'zinser':'data/Zinser_SizeDist_calibrated-26-6-itest.csv',         
}

desc = {
    'seaflow':'SeaFlow dataset',
    'zinser':'Zinser dataset',    
}

size_units = 'fg C cell$^{-1}$'

data_gridded = {}
for dataname in datafiles:
    data_gridded[dataname] = {}
    with nc4.Dataset(datafiles[dataname]) as nc:
        for var in nc.variables:
            data_gridded[dataname][var] = nc.variables[var][:]

    # create "counts" entry
    if 'count' in data_gridded[dataname]:
        data_gridded[dataname]['counts'] = (data_gridded[dataname]['count'][None,:] * data_gridded[dataname]['w_obs']).astype(int)
    elif 'abundance' in data_gridded[dataname]:
        logging.warning('{}: Using "abundance" data to generate count data for the model.'.format(dataname))
        data_gridded[dataname]['counts'] = (data_gridded[dataname]['count'][None,:] * data_gridded[dataname]['w_obs']).astype(int)
    else:
        raise RuntimeError('Cannot find a "count" or "abundance" entry in "{}".'.format(datafiles[dataname]))
        
    
    # add description
    desc[dataname] += ' (m={data[m]}, $\Delta_v^{{-1}}$={data[delta_v_inv]})'.format(data=data_gridded[dataname])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

def add_colorbar(ax, **cbarargs):
    axins_cbar = inset_axes(ax, width='3%', height='90%', loc=5, bbox_to_anchor=(0.05,0.0,1,1), bbox_transform=ax.transAxes)
    mpl.colorbar.ColorbarBase(axins_cbar, orientation='vertical', **cbarargs)

if show_data:
    for i,dataname in enumerate(data_gridded):
        nrows = 3

        v_min = data_gridded[dataname]['v_min']
        delta_v = 1.0/data_gridded[dataname]['delta_v_inv']
        v = v_min * 2**(np.arange(data_gridded[dataname]['m'])*delta_v) 

        fig,axs = plt.subplots(nrows=nrows, sharex=True, figsize=(12,4*nrows))

        ax = axs[0]
        ax.set_title('raw '+desc[dataname], size=20)
        ax.plot(data_gridded[dataname]['time'], data_gridded[dataname]['PAR'], color='gold')
        ax.set(ylabel='PAR')

        ax = axs[1]
        pc = ax.pcolormesh(data_gridded[dataname]['time'], v, data_gridded[dataname]['w_obs'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='size class proportion')

        ax = axs[2]
        pc = ax.pcolormesh(data_gridded[dataname]['time'], v, data_gridded[dataname]['counts'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='counts')
    axs[-1].set_xlabel=('time (minutes)')
None

# %% [markdown]
# ## process data and plot it

# %%
# prepare data for Stan model

seaflow_filter_par = False

if 'data' not in globals():
    data = {}

for dataname in data_gridded:
    dt = 20 # in units of minutes
    
    data[dataname] = {'dt':dt}
    for v in ('m','v_min','delta_v_inv'):
        data[dataname][v] = data_gridded[dataname][v]

    if 'seaflow' in dataname:
        limit_days = None
        data[dataname]['obs'] = data_gridded[dataname]['w_obs']
        data[dataname]['t_obs'] = data_gridded[dataname]['time']
        if limit_days is None:
            limit_days = int(np.ceil(data[dataname]['t_obs'][-1]/1440))
        
        if seaflow_filter_par:
            # median filter PAR
            # see: medianfilter_par.ipynb
            n = len(data_gridded[dataname]['PAR'])
            wsh = 30 # half of median filter window size; window size is 2*wsh+1
            par = np.array([np.median(data_gridded[dataname]['PAR'][max(0,i-wsh):min(n,i+wsh+1)]) for i in range(n)])
        else:
            par = data_gridded[dataname]['PAR']
    else:
        limit_days = 2
        
        data[dataname]['obs'] = data_gridded[dataname]['w_obs']
        data[dataname]['t_obs'] = data_gridded[dataname]['time']
        par = data_gridded[dataname]['PAR']
        
    if limit_days > 0:
        limit_minutes = limit_days*1440
        
        ind_obs = data[dataname]['t_obs'] < limit_minutes
        
        if not np.all(ind_obs):
            print('{}: limit_days is set to {}, removing {}/{} observation times'.format(dataname, limit_days, ind_obs.size-np.count_nonzero(ind_obs), ind_obs.size))
        
        data[dataname]['t_obs'] = data[dataname]['t_obs'][ind_obs]
        data[dataname]['obs'] = data[dataname]['obs'][:,ind_obs]
        
        data[dataname]['nt'] = int(limit_minutes//data[dataname]['dt'])

    data[dataname]['nt_obs'] = data[dataname]['t_obs'].size
    
    if use_testdata:
        # load cross-validation testing indices and add them to data
        data[dataname]['i_test'] = np.loadtxt(itestfiles[dataname]).astype(int)
        # remove last index, so that dimensions agree
        data[dataname]['i_test'] = data[dataname]['i_test'][:-1]
    else:
        # set all indices to zero
        data[dataname]['i_test'] = np.zeros(data[dataname]['nt_obs'], dtype=int)
        
    # switch on or off data fitting
    data[dataname]['prior_only'] = int(prior_only)
    
    # add light data
    t = np.arange(data[dataname]['nt'])*data[dataname]['dt']
    data[dataname]['E'] = np.interp(t, xp=data_gridded[dataname]['time'], fp=par)
    
    # real count data
    data[dataname]['obs_count'] = data_gridded[dataname]['counts'][:, ind_obs]
    
    # consistency check
    if len(data[dataname]['i_test']) != data[dataname]['nt_obs']:
        raise ValueError('Invalid number of testing indices for "{}" (expected {}, got {}).'.format(dataname,data[dataname]['nt_obs'],len(data[dataname]['i_test'])))

# %%
if show_data:
    for i,dataname in enumerate(data):
        nrows = 3

        v_min = data[dataname]['v_min']
        delta_v = 1.0/data[dataname]['delta_v_inv']
        v = v_min * 2**(np.arange(data[dataname]['m'])*delta_v) 
        t = np.arange(data[dataname]['nt'])*data[dataname]['dt']


        fig,axs = plt.subplots(nrows=nrows, sharex=True, figsize=(12,4*nrows))

        ax = axs[0]
        ax.set_title('processed '+desc[dataname], size=20)
        ax.plot(t, data[dataname]['E'], color='gold')
        ax.set(ylabel='E')

        ax = axs[1]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, data[dataname]['obs'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='size class proportion')
        ax.set_xlim(left=0.0)

        ax = axs[2]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, data[dataname]['obs_count'], shading='auto')
        ax.set(ylabel='size ({})'.format(size_units))
        #ax.text(0.01, 0.95, desc[dataname], color='white', size=16, transform=ax.transAxes, ha='left', va='top')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='counts')
        ax.set_xlim(left=0.0)
    axs[-1].set_xlabel('time (minutes)')
None

# %% [markdown]
# ## run model

# %%
desc_model = {
    #'m1':'m1',
    'm2':'m2',
    #'m3':'m3',
    'm4':'m4',
    #'m5':'m5',
    #'m6':'m6',
    #'m7':'m7',
    #'m8':'m8',
    #'m9':'m9',
    #'m10':'m10',
    #'m11':'m11',
    #'m12':'m12',
    #'m13':'m13',
    #'m14':'m14',
    #'m3u':'m3u',
    #'m6u':'m6u',
    #'m7u':'m7u',
    #'m8u':'m8u',
    #'m9u':'m9u',
    #'m11u':'m11u',
    'm12u':'m12u',
    #'m13u':'m13u',
    #'m14u':'m14u',
    'm15':'m15',
    'm16':'m16',
    'm4s6':'m4 + spline6',
    'm12us6':'m12u + spline6',
    'm15s6':'m15 + spline6',
    'm16s6':'m16 + spline6',
}
# preparing for some regular expression magic
model_code_replacements = {
    'm1':(),
    'm2':(),
    'm3':(),
    'm4':(),
    'm5':(),
    'm6':(),
    'm7':(),
    'm8':(),
    'm9':(),
    'm10':(),
    'm11':(),
    'm12':(),
    'm13':(),
    'm14':(),
    'm3u':(),
    'm6u':(),
    'm7u':(),
    'm8u':(),
    'm9u':(),
    'm11u':(),
    'm12u':(),
    'm13u':(),
    'm14u':(),
    'm15':(),
    'm16':(),
    'm4s6':(('^( *int nknots = *)','6;'),),
    'm12us6':(('^( *int nknots = *)','6;'),),
    'm15s6':(('^( *int nknots = *)','6;'),),
    'm16s6':(('^( *int nknots = *)','6;'),),
}
model_stan_key = {
    'm1':'c1',
    'm2':'c2',
    'm3':'c3',
    'm4':'c4',
    'm5':'c5',
    'm6':'c6',
    'm7':'c7',
    'm8':'c8',
    'm9':'c9',
    'm10':'c10',
    'm11':'c11',
    'm12':'c12',
    'm13':'c13',
    'm14':'c14',
    'm3u':'c3u',
    'm6u':'c6u',
    'm7u':'c7u',
    'm8u':'c8u',
    'm9u':'c9u',
    'm11u':'c11u',
    'm12u':'c12u',
    'm13u':'c13u',
    'm14u':'c14u',
    'm15':'c15',
    'm16':'c16',
    'm4s6':'c4s',
    'm12us6':'c12us',
    'm15s6':'c15s',
    'm16s6':'c16s',
}
stan_files = {
    'c1':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_freedelta_normparam_trackgrowthvol_xval2.stan',
    'c2':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_normparam_trackgrowthvol_xval2.stan',
    'c3':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_gammaiv6_normparam_trackgrowthvol_xval2.stan',
    'c4':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_respv1_normparam_trackgrowthvol_xval2.stan',
    'c5':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_respv2_normparam_trackgrowthvol_xval2.stan',
    'c6':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_respiv6_normparam_trackgrowthvol_xval2.stan',
    'c7':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_respiv7_normparam_trackgrowthvol_xval2.stan',
    'c8':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_respiv6_normparam_trackgrowthvol_xval2.stan',
    'c9':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_respiv7_normparam_trackgrowthvol_xval2.stan',
    'c10':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_respv2_normparam_trackgrowthvol_xval2.stan',
    'c11':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_resp_gammaiv6_normparam_trackgrowthvol_xval2.stan',
    'c12':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_resp_gammaiv7_normparam_trackgrowthvol_xval2.stan',
    'c13':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_resp_gammaiv6_normparam_trackgrowthvol_xval2.stan',
    'c14':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_resp_gammaiv7_normparam_trackgrowthvol_xval2.stan',
    'c3u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_gammaiv8_normparam_trackgrowthvol_xval2.stan',
    'c6u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_respiv8_normparam_trackgrowthvol_xval2.stan',
    'c7u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_respiv9_normparam_trackgrowthvol_xval2.stan',
    'c8u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_respiv8_normparam_trackgrowthvol_xval2.stan',
    'c9u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_respiv9_normparam_trackgrowthvol_xval2.stan',
    'c11u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_resp_gammaiv8_normparam_trackgrowthvol_xval2.stan',
    'c12u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_resp_gammaiv9_normparam_trackgrowthvol_xval2.stan',
    'c13u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_resp_gammaiv8_normparam_trackgrowthvol_xval2.stan',
    'c14u':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2-lightsig_resp_gammaiv9_normparam_trackgrowthvol_xval2.stan',
    'c15':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_resp_freegamma_normparam_trackgrowthvol_xval2.stan',
    'c16':'stancode_gallery3/matrixmodel_mlmultinom_estinilnorm2_monodelta2_freeresp_freegamma_normparam_trackgrowthvol_xval2.stan',
    'c4s':'../g3_timedep/matrixmodel_mlmultinom_estinilnorm2_monodelta2-timespline_respv1_normparam_trackgrowthvol_xval2.stan',
    'c12us':'../g3_timedep/matrixmodel_mlmultinom_estinilnorm2_monodelta2-timespline_resp_gammaiv9_normparam_trackgrowthvol_xval2.stan',
    'c15s':'../g3_timedep/matrixmodel_mlmultinom_estinilnorm2_monodelta2-timespline_resp_freegamma_normparam_trackgrowthvol_xval2.stan',
    'c16s':'../g3_timedep/matrixmodel_mlmultinom_estinilnorm2_monodelta2-timespline_freeresp_freegamma_normparam_trackgrowthvol_xval2.stan',
}

# %%
import pystan
import re
import time

def get_max_rhat(fit):
    s = fit.summary()
    irhat = s['summary_colnames'].index("Rhat")
    return np.nanmax(s['summary'][:,irhat])

if 'models' not in globals():
    models = {}
if 'mcmcs' not in globals():
    mcmcs = {}
if 'maxrhats' not in globals():
    maxrhats = {}
if 'sampling_time' not in globals():
    sampling_time = {}
if 'num_tries' not in globals():
    num_tries = 3
    
try_again = True
refit_all = False

refit_required = {}
stan_base_code = {}
for key,stan_file in stan_files.items():
    with open(stan_file) as f:
        stan_base_code[key] = f.read()

stan_code = {}
for model in desc_model:
    code_split = stan_base_code[model_stan_key[model]].split('\n')
    code_split_new = []
    for line in code_split:
        line_new = line
        for replacement in model_code_replacements[model]:
            m = re.match(replacement[0],line_new)
            if m:
                line_new = m.groups(0)[0]+replacement[1]
                print('{}: patching in "{}"'.format(model, line_new))
        code_split_new.append(line_new)
                
    stan_code[model] = '\n'.join(code_split_new)

for model in desc_model:
    refit_required[model] = True
    if model in models and models[model].model_code == stan_code[model]:
        print('{}: unchanged code, not recompiling'.format(model))
        refit_required[model] = False
    else:
        if model in models:
            print('{}: code change detected, recompiling'.format(model))
        else:
            print('{}: compiling'.format(model))
        models[model] = pystan.StanModel(model_code=stan_code[model], model_name=model, obfuscate_model_name=False)

# run a bunch of experiments -- this may take a while
for model in models:
    if model not in maxrhats:
        maxrhats[model] = {}
    if model not in sampling_time:
        sampling_time[model] = {}
    for dataname in data:
        if dataname not in maxrhats[model]:
            maxrhats[model][dataname] = []
        if dataname not in sampling_time[model]:
            sampling_time[model][dataname] = []
        if model in mcmcs:
            if dataname in mcmcs[model] and not refit_all and not refit_required[model]:
                print('{}: found existing results:'.format(model))
                print('{} ({})'.format(model, desc_model[model])) 
                print('\n'.join(x for x in mcmcs[model][dataname].__str__().split('\n') if '[' not in x))
                rhat_max = get_max_rhat(mcmcs[model][dataname])
                if try_again and rhat_max >= 1.1:
                    print('{}: found Rhat={:.3f}, trying again'.format(model,rhat_max))
                else:
                    print('{}: not re-running model'.format(model))
                    print()
                    continue
            elif refit_all:
                print('{}: refit_all is active, re-running model'.format(model))
            elif refit_required[model]:
                print('{}: change in model code requires re-running model'.format(model))
        else:
            mcmcs[model] = {}
        for itry in range(num_tries):
            t0 = time.time()
            mcmcs[model][dataname] = models[model].sampling(data=data[dataname], iter=2000, chains=num_chains)
            sampling_time[model][dataname].append(time.time() - t0) # in seconds
            # get max Rhat
            rhat_max = get_max_rhat(mcmcs[model][dataname])
            maxrhats[model][dataname].append(rhat_max)
            print('{}: in try {}/{} found Rhat={:.3f}'.format(model, itry+1, num_tries, rhat_max), end='')
            if rhat_max < 1.1 or itry == num_tries - 1:
                print()
                break
            print(', trying again')
        
        print('{} ({})'.format(model, desc_model[model])) 
        print('\n'.join(x for x in mcmcs[model][dataname].__str__().split('\n') if '[' not in x))
        print()
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m2 NOW.
# m4s6: patching in "    int nknots = 6;"
# m12us6: patching in "    int nknots = 6;"
# m15s6: patching in "    int nknots = 6;"
# m16s6: patching in "    int nknots = 6;"
# m2: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpi5ikbteu/stanfit4m2_6087251436355746221.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m4 NOW.
# m4: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpn13_yhkt/stanfit4m4_8250465493783631732.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m12u NOW.
# m12u: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmp0onnnwzs/stanfit4m12u_607106669580725507.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m15 NOW.
# m15: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpz_i8ajgh/stanfit4m15_4824002495436573107.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m16 NOW.
# m16: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpiy535gnc/stanfit4m16_6939714881555600026.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m4s6 NOW.
# m4s6: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpal6uyswl/stanfit4m4s6_4237860899361397222.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m12us6 NOW.
# m12us6: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpbdhscqsq/stanfit4m12us6_849379441972729367.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m15s6 NOW.
# m15s6: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpy96kdrsy/stanfit4m15s6_5374565380891096753.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL m16s6 NOW.
# m16s6: compiling
# /software/python/anaconda/3-2020.07/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpsa5840vo/stanfit4m16s6_2119343436051689018.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# WARNING:pystan:n_eff / iter for parameter resp_size_loss[114] is nan!
# WARNING:pystan:Rhat for parameter resp_size_loss[44] is nan!
# WARNING:pystan:Rhat for parameter growth_size_gain[107] is nan!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m2: in try 1/3 found Rhat=1.007
# m2 (m2)
# Inference for Stan model: m2.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              45.59    0.22   9.37  30.52  38.57  44.53  51.27  66.98   1783    1.0
# gamma_max                1.7  4.3e-4   0.04   1.62   1.67    1.7   1.72   1.78   9201    1.0
# rho_max                 3.28    0.02   1.91   0.16    1.6   3.31   4.95   6.38   9201    1.0
# E_star                 329.2     0.6  53.77 237.18 291.27 324.79 361.72 449.24   7987    1.0
# sigma                 712.96     0.3  29.48 655.94 693.27 712.28 732.41 772.28   9406    1.0
# divrate                 0.86  2.5e-4   0.02   0.81   0.84   0.86   0.88   0.91   9117    1.0
# lp__                  -2.2e6    0.54  24.95 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6   2098    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 07:53:41 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:n_eff / iter for parameter mod_obspos[23,10] is 0.0009434458380686365!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,17] is 0.0005359410765485019!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,22] is 0.0005346539981258075!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,28] is 0.000513524699013355!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,33] is 0.0005190509563479723!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,39] is 0.0005317439296020881!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,44] is 0.0005109381219334206!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[25] is 0.0005246967417976115!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[127] is 0.0005158690086594326!
# WARNING:pystan:n_eff / iter for parameter total_size[81] is 0.0005358151772649844!
# WARNING:pystan:n_eff / iter for parameter cell_count[37] is 0.0005281757618752481!
# WARNING:pystan:n_eff / iter for parameter cell_count[136] is 0.0005222898637606833!
# WARNING:pystan:Rhat for parameter mod_obspos[6,8] is 3.352726136812313!
# WARNING:pystan:Rhat for parameter mod_obspos[4,14] is 3.11921960386856!
# WARNING:pystan:Rhat for parameter mod_obspos[14,20] is 4.630222281236333!
# WARNING:pystan:Rhat for parameter mod_obspos[5,26] is 6.058343478266656!
# WARNING:pystan:Rhat for parameter mod_obspos[2,32] is 2.3869879881904685!
# WARNING:pystan:Rhat for parameter mod_obspos[10,37] is 4.1520374536126745!
# WARNING:pystan:Rhat for parameter mod_obspos[13,43] is 6.80746112617419!
# WARNING:pystan:Rhat for parameter resp_size_loss[104] is 1.118226745449385!
# WARNING:pystan:Rhat for parameter growth_size_gain[71] is 2.8997291875467055!
# WARNING:pystan:Rhat for parameter total_size[40] is 4.395026726791316!
# WARNING:pystan:Rhat for parameter cell_count[12] is 3.2176605792761963!
# WARNING:pystan:Rhat for parameter cell_count[127] is 4.49921534520748!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m4: in try 2/3 found Rhat=21.759, trying again
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,11] is 0.0005435747483061592!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,18] is 0.000585611865985952!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[3,24] is 0.0005247455935505353!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,29] is 0.0005364656536869737!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,35] is 0.0005834879306778638!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,41] is 0.0005532226042739595!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,46] is 0.0005726171581426321!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[77] is 0.0006015149554182887!
# WARNING:pystan:n_eff / iter for parameter total_size[37] is 0.0005412745210790919!
# WARNING:pystan:n_eff / iter for parameter total_size[136] is 0.0005285202918047455!
# WARNING:pystan:n_eff / iter for parameter cell_count[92] is 0.0005472650626113484!
# WARNING:pystan:Rhat for parameter mod_obspos[7,6] is 2.169788390238928!
# WARNING:pystan:Rhat for parameter mod_obspos[12,12] is 2.8411295607124702!
# WARNING:pystan:Rhat for parameter mod_obspos[11,19] is 4.099450991830196!
# WARNING:pystan:Rhat for parameter mod_obspos[18,24] is 2.3617762042935433!
# WARNING:pystan:Rhat for parameter mod_obspos[2,31] is 3.5239378088248534!
# WARNING:pystan:Rhat for parameter mod_obspos[14,36] is 3.6457280170465136!
# WARNING:pystan:Rhat for parameter mod_obspos[20,42] is 2.4540621466248638!
# WARNING:pystan:Rhat for parameter mod_obspos[21,47] is 1.330924467483923!
# WARNING:pystan:Rhat for parameter growth_size_gain[69] is 2.464505763069086!
# WARNING:pystan:Rhat for parameter total_size[38] is 3.5157346804676983!
# WARNING:pystan:Rhat for parameter cell_count[10] is 2.6170181424226837!
# WARNING:pystan:Rhat for parameter cell_count[125] is 3.7431290606913086!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m4: in try 3/3 found Rhat=22.042
# m4 (m4)
# Inference for Stan model: m4.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              45.88    0.35   9.47  30.32  38.83   44.8  51.99   66.4    716   1.02
# gamma_max               1.71    0.02   0.05   1.62   1.67   1.71   1.74   1.81     10    1.2
# rho_max               3.0e-3  3.5e-4 2.9e-3 8.5e-5 9.1e-4 2.2e-3 4.4e-3   0.01     68   1.04
# E_star                274.19   70.51 131.12   3.06 263.73  309.4 350.97 444.34      3   2.69
# sigma                 714.49    0.38  29.52 658.12 693.62 713.84 733.79 774.94   5900   1.01
# divrate                 0.89    0.05   0.08   0.81   0.85   0.86   0.89   1.09      3   3.64
# lp__                  -2.2e6    0.51   24.9 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6   2341    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 08:57:59 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,11] is 0.0007974704794224794!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,17] is 0.0007751506045985643!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,23] is 0.0005245362178998741!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,28] is 0.0007985309247074527!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,34] is 0.0005512906907543497!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,40] is 0.0005511886350478825!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,45] is 0.0005200680548718315!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[62] is 0.0005657072146241351!
# WARNING:pystan:n_eff / iter for parameter total_size[16] is 0.0008150256971990176!
# WARNING:pystan:n_eff / iter for parameter total_size[115] is 0.0005347553760476622!
# WARNING:pystan:n_eff / iter for parameter cell_count[71] is 0.0005277507453896209!
# WARNING:pystan:Rhat for parameter mod_obspos[3,4] is 1.364676609792783!
# WARNING:pystan:Rhat for parameter mod_obspos[15,10] is 4.9558141038131325!
# WARNING:pystan:Rhat for parameter mod_obspos[16,16] is 1.1268358306301411!
# WARNING:pystan:Rhat for parameter mod_obspos[19,22] is 2.4584449285993832!
# WARNING:pystan:Rhat for parameter mod_obspos[18,28] is 1.4132924737708172!
# WARNING:pystan:Rhat for parameter mod_obspos[10,34] is 3.4425348690566246!
# WARNING:pystan:Rhat for parameter mod_obspos[10,40] is 3.5905964729268933!
# WARNING:pystan:Rhat for parameter mod_obspos[23,45] is 1.2823636778491205!
# WARNING:pystan:Rhat for parameter growth_size_gain[47] is nan!
# WARNING:pystan:Rhat for parameter total_size[15] is 1.609408051172116!
# WARNING:pystan:Rhat for parameter total_size[130] is 4.481247081116626!
# WARNING:pystan:Rhat for parameter cell_count[102] is 3.6128351456603642!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m12u: in try 1/3 found Rhat=17.967, trying again
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,11] is 0.0007544093969972293!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,17] is 0.0008027447428693147!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,23] is 0.0005250978603028061!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,28] is 0.0006626075838037833!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,34] is 0.0005769622917690851!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,39] is 0.0006528266761941591!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,45] is 0.0005291381859881253!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[60] is 0.0005619477031836043!
# WARNING:pystan:n_eff / iter for parameter total_size[14] is 0.0008261383064142519!
# WARNING:pystan:n_eff / iter for parameter total_size[113] is 0.0005351605594655928!
# WARNING:pystan:n_eff / iter for parameter cell_count[69] is 0.0005285841270833019!
# WARNING:pystan:Rhat for parameter mod_obspos[2,4] is 1.1800646618405513!
# WARNING:pystan:Rhat for parameter mod_obspos[15,10] is 4.594573102582917!
# WARNING:pystan:Rhat for parameter mod_obspos[16,16] is 1.1233470442739582!
# WARNING:pystan:Rhat for parameter mod_obspos[20,22] is 1.578516694021226!
# WARNING:pystan:Rhat for parameter mod_obspos[18,28] is 1.4092929848525582!
# WARNING:pystan:Rhat for parameter mod_obspos[11,34] is 2.9848779287640177!
# WARNING:pystan:Rhat for parameter mod_obspos[10,40] is 3.566004876595907!
# WARNING:pystan:Rhat for parameter mod_obspos[22,45] is 1.5780167752380398!
# WARNING:pystan:Rhat for parameter growth_size_gain[14] is 1.253008312474496!
# WARNING:pystan:Rhat for parameter growth_size_gain[129] is 4.15253954241816!
# WARNING:pystan:Rhat for parameter total_size[99] is 3.8252871242985336!
# WARNING:pystan:Rhat for parameter cell_count[71] is 4.151591146180706!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m12u: in try 2/3 found Rhat=19.624, trying again
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,11] is 0.0007620692185136686!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[2,18] is 0.0006118595126140679!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,23] is 0.0005254095529488297!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,28] is 0.0006714533508420444!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,34] is 0.0005658711523509034!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,39] is 0.0008948727504520602!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,45] is 0.0005272611419972321!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[62] is 0.0005705271696839987!
# WARNING:pystan:n_eff / iter for parameter total_size[16] is 0.000854117506555524!
# WARNING:pystan:n_eff / iter for parameter total_size[115] is 0.0005359765752127489!
# WARNING:pystan:n_eff / iter for parameter cell_count[71] is 0.0005298786918016062!
# WARNING:pystan:Rhat for parameter mod_obspos[4,4] is 1.295893699648217!
# WARNING:pystan:Rhat for parameter mod_obspos[17,10] is 4.646003770629121!
# WARNING:pystan:Rhat for parameter mod_obspos[3,17] is 3.4420402776619365!
# WARNING:pystan:Rhat for parameter mod_obspos[2,23] is 2.6256715577876015!
# WARNING:pystan:Rhat for parameter mod_obspos[2,29] is 3.6642677327639124!
# WARNING:pystan:Rhat for parameter mod_obspos[14,34] is 4.383328370999173!
# WARNING:pystan:Rhat for parameter mod_obspos[13,40] is 2.3513565232645988!
# WARNING:pystan:Rhat for parameter mod_obspos[3,46] is 2.6248656626950346!
# WARNING:pystan:Rhat for parameter growth_size_gain[21] is 3.529132392755528!
# WARNING:pystan:Rhat for parameter growth_size_gain[136] is 3.3976591749330742!
# WARNING:pystan:Rhat for parameter total_size[106] is 3.7800745749930798!
# WARNING:pystan:Rhat for parameter cell_count[78] is 3.8448295769886465!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m12u: in try 3/3 found Rhat=19.709
# m12u (m12u)
# Inference for Stan model: m12u.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              61.33     0.2   6.51  48.35  56.46   61.8  66.67  71.47   1069   1.02
# gamma_max               3.52  5.2e-3   0.27   3.02   3.33    3.5    3.7   4.06   2657   1.01
# rho_max               3.0e-3  3.9e-4 2.7e-3 8.5e-5 9.8e-4 2.2e-3 4.2e-3   0.01     50   1.05
# E_star                187.87   75.49 134.51   2.89   4.16 250.99 290.17 359.16      3   4.15
# sigma                 789.94    3.63  34.39 724.78 766.72 789.14 811.77 861.66     90   1.03
# exponent_gamma           0.5  8.7e-4   0.05    0.4   0.47    0.5   0.54    0.6   3572    1.0
# divrate                 1.03    0.06    0.1   0.91   0.95   0.98   1.15    1.2      3    4.0
# lp__                  -2.2e6    0.71  25.03 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6   1250   1.02
#
# Samples were drawn using NUTS at Wed Nov 18 09:59:09 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:n_eff / iter for parameter mod_obspos[11,12] is 0.0005815426196009156!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,19] is 0.0005255624753911544!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[20,24] is 0.0008916239775161141!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,31] is 0.0005250304767719957!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,36] is 0.0005371137064163293!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,42] is 0.0007078745745564297!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,47] is 0.0005261038289073963!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[98] is nan!
# WARNING:pystan:n_eff / iter for parameter total_size[55] is 0.0005200977904302648!
# WARNING:pystan:n_eff / iter for parameter cell_count[11] is 0.0005541343230144724!
# WARNING:pystan:n_eff / iter for parameter cell_count[110] is 0.0005292554247636632!
# WARNING:pystan:Rhat for parameter mod_obspos[10,7] is 1.9638544968890037!
# WARNING:pystan:Rhat for parameter mod_obspos[18,13] is 1.3623794173733028!
# WARNING:pystan:Rhat for parameter mod_obspos[11,20] is 3.52258732657901!
# WARNING:pystan:Rhat for parameter mod_obspos[19,25] is 1.7703238579040905!
# WARNING:pystan:Rhat for parameter mod_obspos[2,32] is 1.808366820244233!
# WARNING:pystan:Rhat for parameter mod_obspos[14,37] is 3.239554116677488!
# WARNING:pystan:Rhat for parameter mod_obspos[20,43] is 2.9239854405677512!
# WARNING:pystan:Rhat for parameter resp_size_loss[18] is 1.1795618372881842!
# WARNING:pystan:Rhat for parameter resp_size_loss[126] is 1.333565046131767!
# WARNING:pystan:Rhat for parameter growth_size_gain[93] is 7.942535228862723!
# WARNING:pystan:Rhat for parameter total_size[65] is 4.430683215871845!
# WARNING:pystan:Rhat for parameter cell_count[37] is 4.091570221985656!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m15: in try 1/3 found Rhat=21.470, trying again
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# m15: in try 2/3 found Rhat=1.002
# m15 (m15)
# Inference for Stan model: m15.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              36.86    0.23   9.02  22.34  30.44  35.76  42.11  57.99   1531    1.0
# gamma_mu                1.62  2.0e-3   0.13   1.37   1.54   1.62    1.7   1.88   4047    1.0
# gamma_sigma              0.5  1.6e-3    0.1   0.35   0.43   0.48   0.55   0.73   3806    1.0
# rho_max               5.8e-3  4.6e-5 4.4e-3 2.3e-4 2.3e-3 4.9e-3 8.3e-3   0.02   9065    1.0
# E_star                379.99    0.59  47.38 296.97 347.32 376.74 409.22 482.67   6487    1.0
# sigma                 1072.5    0.43  46.06 985.53 1040.7 1071.6 1103.1 1164.0  11594    1.0
# divrate                 0.88  2.8e-4   0.02   0.84   0.86   0.88   0.89   0.91   4682    1.0
# lp__                  -2.2e6    0.56  25.34 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6   2063    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 11:04:12 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:n_eff / iter for parameter mod_obspos[17,12] is 0.0007262677045333105!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,33] is 0.000675552169053716!
# WARNING:pystan:n_eff / iter for parameter resp_size_loss[20] is 0.0005326392469390894!
# WARNING:pystan:n_eff / iter for parameter resp_size_loss[115] is 0.000508006488710964!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[92] is 0.00052476466874979!
# WARNING:pystan:Rhat for parameter mod_obspos[8,5] is 1.1332114008757472!
# WARNING:pystan:Rhat for parameter mod_obspos[14,12] is 1.371239386117025!
# WARNING:pystan:Rhat for parameter mod_obspos[3,23] is 1.1372921981409725!
# WARNING:pystan:Rhat for parameter mod_obspos[2,31] is 1.3140952024332528!
# WARNING:pystan:Rhat for parameter mod_obspos[4,41] is 1.6761781502235948!
# WARNING:pystan:Rhat for parameter resp_size_loss[30] is 5.084092475027663!
# WARNING:pystan:Rhat for parameter resp_size_loss[139] is 7.996597980367315!
# WARNING:pystan:Rhat for parameter growth_size_gain[107] is nan!
# WARNING:pystan:Rhat for parameter cell_count[40] is 1.1732622741865129!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# m16: in try 1/3 found Rhat=28.176, trying again
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,15] is 0.0007548650094622476!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,34] is 0.000668226461128912!
# WARNING:pystan:n_eff / iter for parameter resp_size_loss[42] is 0.0005164122912453793!
# WARNING:pystan:n_eff / iter for parameter resp_size_loss[136] is 0.0005080749747180017!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[116] is nan!
# WARNING:pystan:Rhat for parameter mod_obspos[13,7] is 1.1084348712743124!
# WARNING:pystan:Rhat for parameter mod_obspos[5,15] is 1.4411002362221987!
# WARNING:pystan:Rhat for parameter mod_obspos[7,26] is 1.3836435096460513!
# WARNING:pystan:Rhat for parameter mod_obspos[17,33] is 2.035830577796849!
# WARNING:pystan:Rhat for parameter mod_obspos[5,44] is 1.4680924181758241!
# WARNING:pystan:Rhat for parameter resp_size_loss[67] is 5.313238683286892!
# WARNING:pystan:Rhat for parameter growth_size_gain[32] is nan!
# WARNING:pystan:Rhat for parameter total_size[1] is 1.6946610170856378!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# m16: in try 2/3 found Rhat=30.432, trying again
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,15] is 0.0008195894886284395!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[4,40] is 0.0009621792824560434!
# WARNING:pystan:n_eff / iter for parameter resp_size_loss[49] is 0.0005160179816361501!
# WARNING:pystan:n_eff / iter for parameter resp_size_loss[143] is 0.0005119182955905354!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[127] is 0.0005280289648785181!
# WARNING:pystan:Rhat for parameter mod_obspos[17,8] is 1.459425822922872!
# WARNING:pystan:Rhat for parameter mod_obspos[12,16] is 2.0888156105933415!
# WARNING:pystan:Rhat for parameter mod_obspos[15,27] is 1.5553773958904809!
# WARNING:pystan:Rhat for parameter mod_obspos[20,34] is 1.222872038191033!
# WARNING:pystan:Rhat for parameter mod_obspos[16,45] is 3.666792952737946!
# WARNING:pystan:Rhat for parameter resp_size_loss[90] is 4.512997051794861!
# WARNING:pystan:Rhat for parameter growth_size_gain[58] is 1.7994720850812893!
# WARNING:pystan:Rhat for parameter total_size[35] is 1.3946026982349629!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# m16: in try 3/3 found Rhat=29.280
# m16 (m16)
# Inference for Stan model: m16.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max               8.87    0.16   3.72   5.05   6.64   8.05   9.98  17.92    556   1.02
# gamma_mu                1.43    0.03   0.18   1.08   1.31   1.42   1.55   1.79     30   1.06
# gamma_sigma             0.76    0.03   0.14   0.54   0.66   0.74   0.84   1.08     23   1.08
# rho_mu                  0.29    0.05   0.11   0.15   0.21   0.26   0.37   0.53      4   1.91
# rho_sigma               0.21    0.04   0.08   0.11   0.15   0.18   0.27   0.39      4   1.92
# E_star                201.95   81.97 144.21   1.28   1.76  279.4  310.8  364.8      3   5.58
# sigma                 1327.4   40.16  91.51 1178.4 1261.3 1314.5 1389.1 1521.4      5   1.52
# divrate                 0.63  4.2e-3   0.03   0.57   0.61   0.63   0.65   0.69     56   1.06
# lp__                  -2.2e6   16.74   38.7 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6      5   1.51
#
# Samples were drawn using NUTS at Wed Nov 18 12:49:02 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:n_eff / iter for parameter mod_obspos[8,14] is 0.0007949010550415178!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,22] is 0.0006787940702370542!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[12,30] is 0.0009394957150710582!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[10,37] is 0.0007468249189939992!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,44] is 0.0005541775538993107!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[92] is 0.0005987119058669439!
# WARNING:pystan:n_eff / iter for parameter total_size[73] is 0.0007595082581130618!
# WARNING:pystan:n_eff / iter for parameter cell_count[56] is 0.0006327815064304479!
# WARNING:pystan:Rhat for parameter tau[6] is 1.4945814835811098!
# WARNING:pystan:Rhat for parameter mod_obspos[4,10] is 1.1361496604337697!
# WARNING:pystan:Rhat for parameter mod_obspos[9,17] is 1.8426209064404673!
# WARNING:pystan:Rhat for parameter mod_obspos[16,23] is 1.18802038764936!
# WARNING:pystan:Rhat for parameter mod_obspos[13,29] is 1.4486892964225464!
# WARNING:pystan:Rhat for parameter mod_obspos[8,35] is 1.6340442371923027!
# WARNING:pystan:Rhat for parameter mod_obspos[13,41] is 1.1176224103180161!
# WARNING:pystan:Rhat for parameter mod_obspos[11,47] is 1.9632185809039686!
# WARNING:pystan:Rhat for parameter growth_size_gain[125] is 4.335635723346477!
# WARNING:pystan:Rhat for parameter total_size[116] is 1.8053426088142672!
# WARNING:pystan:Rhat for parameter cell_count[101] is 1.7128961464879189!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m4s6: in try 1/3 found Rhat=9.290, trying again
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,14] is 0.0007405376130657593!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[13,22] is 0.000783591120794505!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[7,31] is 0.0008206084143771811!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[6,38] is 0.0007377693751807077!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[25,44] is 0.0009870103148916156!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[107] is nan!
# WARNING:pystan:n_eff / iter for parameter total_size[106] is 0.0007449878732579457!
# WARNING:pystan:n_eff / iter for parameter cell_count[87] is 0.0009450631071267805!
# WARNING:pystan:Rhat for parameter tau[71] is 1.3643353970945422!
# WARNING:pystan:Rhat for parameter mod_obspos[10,11] is 1.608555783941962!
# WARNING:pystan:Rhat for parameter mod_obspos[8,19] is 1.9558479243355529!
# WARNING:pystan:Rhat for parameter mod_obspos[16,24] is 1.2011936568283637!
# WARNING:pystan:Rhat for parameter mod_obspos[16,30] is 1.2190386140562421!
# WARNING:pystan:Rhat for parameter mod_obspos[12,36] is 1.7369541450898796!
# WARNING:pystan:Rhat for parameter mod_obspos[7,43] is 1.8405382188166426!
# WARNING:pystan:Rhat for parameter growth_size_gain[36] is nan!
# WARNING:pystan:Rhat for parameter total_size[28] is 1.7943515017560316!
# WARNING:pystan:Rhat for parameter total_size[142] is 1.8381262312880229!
# WARNING:pystan:Rhat for parameter cell_count[126] is 1.8150832427732633!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m4s6: in try 2/3 found Rhat=8.068, trying again
# WARNING:pystan:n_eff / iter for parameter mod_obspos[9,14] is 0.0007525464494287484!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[14,22] is 0.0008707444905170688!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[5,32] is 0.000844428906414142!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[16,38] is 0.000995585251305333!
# WARNING:pystan:n_eff / iter for parameter mod_obspos[15,45] is 0.0005771624250826746!
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[121] is nan!
# WARNING:pystan:n_eff / iter for parameter total_size[121] is 0.0007583047828852344!
# WARNING:pystan:n_eff / iter for parameter cell_count[103] is 0.0007831783732101428!
# WARNING:pystan:Rhat for parameter mod_obspos[6,4] is 1.153998263450453!
# WARNING:pystan:Rhat for parameter mod_obspos[12,12] is 1.7848400172346959!
# WARNING:pystan:Rhat for parameter mod_obspos[9,20] is 2.016156199740213!
# WARNING:pystan:Rhat for parameter mod_obspos[2,26] is 1.2764077523622832!
# WARNING:pystan:Rhat for parameter mod_obspos[3,32] is 1.619429947379027!
# WARNING:pystan:Rhat for parameter mod_obspos[16,37] is 1.5812755236654994!
# WARNING:pystan:Rhat for parameter mod_obspos[7,44] is 1.7852567882857153!
# WARNING:pystan:Rhat for parameter growth_size_gain[59] is 1.211016107925847!
# WARNING:pystan:Rhat for parameter total_size[52] is 1.9282798451382552!
# WARNING:pystan:Rhat for parameter cell_count[35] is 1.7969920249979892!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m4s6: in try 3/3 found Rhat=8.077
# m4s6 (m4 + spline6)
# Inference for Stan model: m4s6.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              60.97    0.33   7.26  45.47  55.79  61.81  67.09  71.43    486   1.03
# gamma_max                1.4  2.9e-3   0.08   1.25   1.34    1.4   1.46   1.56    750   1.02
# rho_max               3.7e-3  3.9e-4 3.3e-3 1.1e-4 1.2e-3 2.8e-3 5.3e-3   0.01     73   1.03
# E_star                158.49   90.87  165.4   1.36   2.04  40.81 308.26 446.22      3    3.2
# sigma                 781.67    8.04  35.57 713.47 756.81 780.97 805.32 852.04     20   1.09
# divrate                 0.79    0.04   0.08   0.67   0.72   0.77   0.85   0.94      4   1.81
# lp__                  -2.2e6    7.58  28.41 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6     14   1.15
#
# Samples were drawn using NUTS at Wed Nov 18 13:44:25 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:Rhat for parameter mod_obspos[6,7] is 1.150982409044723!
# WARNING:pystan:Rhat for parameter mod_obspos[2,17] is 1.4733031462767874!
# WARNING:pystan:Rhat for parameter mod_obspos[6,24] is 1.308528485986672!
# WARNING:pystan:Rhat for parameter mod_obspos[10,36] is 1.147584757021044!
# WARNING:pystan:Rhat for parameter mod_obspos[16,44] is 1.7325788386796888!
# WARNING:pystan:Rhat for parameter growth_size_gain[108] is nan!
# WARNING:pystan:Rhat for parameter total_size[137] is 1.2410264257318158!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m12us6: in try 1/3 found Rhat=2.263, trying again
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[97] is nan!
# WARNING:pystan:Rhat for parameter mod_obspos[22,8] is 1.1370430139825425!
# WARNING:pystan:Rhat for parameter mod_obspos[23,19] is 1.1391722671676683!
# WARNING:pystan:Rhat for parameter mod_obspos[20,33] is 2.2243219445346236!
# WARNING:pystan:Rhat for parameter mod_obspos[17,43] is 1.6217198069441012!
# WARNING:pystan:Rhat for parameter growth_size_gain[98] is nan!
# WARNING:pystan:Rhat for parameter total_size[137] is 1.182061564937664!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m12us6: in try 2/3 found Rhat=4.220, trying again
# WARNING:pystan:n_eff / iter for parameter growth_size_gain[49] is nan!
# WARNING:pystan:Rhat for parameter mod_obspos[2,8] is 1.4104010725893104!
# WARNING:pystan:Rhat for parameter mod_obspos[9,18] is 1.1890534683300278!
# WARNING:pystan:Rhat for parameter mod_obspos[25,26] is 1.1845341734370651!
# WARNING:pystan:Rhat for parameter mod_obspos[7,40] is 1.141704747495199!
# WARNING:pystan:Rhat for parameter mod_obspos[21,47] is 1.1591123960839078!
# WARNING:pystan:Rhat for parameter total_size[71] is 1.1096255748697093!
# WARNING:pystan:Rhat for parameter cell_count[115] is 1.1474270692205808!
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m12us6: in try 3/3 found Rhat=4.336
# m12us6 (m12u + spline6)
# Inference for Stan model: m12us6.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              69.23    0.04   2.51   62.7  68.05  69.95  71.11  71.93   3662    1.0
# gamma_max               2.81  5.7e-3   0.28    2.3   2.62    2.8    3.0    3.4   2454   1.01
# rho_max               3.3e-3  1.1e-4 2.9e-3 1.0e-4 1.1e-3 2.5e-3 4.7e-3   0.01    751   1.01
# E_star                 39.48   48.48  86.26   1.29   1.78   2.11   2.61 275.07      3   4.34
# sigma                 901.32   13.19  45.57 808.53  871.6 902.28 932.19 989.41     12   1.16
# exponent_gamma          0.52  7.8e-4   0.05   0.43   0.49   0.52   0.56   0.62   3913   1.01
# divrate                 0.88    0.02   0.07   0.75   0.83   0.88   0.92    1.0     13   1.16
# lp__                  -2.2e6    8.64   28.3 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6     11   1.19
#
# Samples were drawn using NUTS at Wed Nov 18 14:37:18 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# m15s6: in try 1/3 found Rhat=1.035
# m15s6 (m15 + spline6)
# Inference for Stan model: m15s6.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              63.95    0.41   6.12  49.45  60.09   65.4   68.9  71.68    222   1.04
# gamma_mu                1.11  2.5e-3    0.1   0.91   1.04    1.1   1.17   1.31   1683   1.01
# gamma_sigma              0.4  1.7e-3   0.08   0.28   0.35   0.39   0.45   0.59   2381    1.0
# rho_max               8.2e-3  1.8e-4 5.9e-3 5.1e-4 3.5e-3 7.1e-3   0.01   0.02   1111   1.01
# E_star                   2.4  7.2e-3   0.44   1.65   2.08   2.37   2.66   3.35   3657    1.0
# sigma                 1432.9    1.56  64.55 1308.6 1387.7 1434.1 1475.7 1560.9   1703    1.0
# divrate                 0.71  9.8e-4   0.03   0.66    0.7   0.71   0.73   0.76    672   1.01
# lp__                  -2.2e6    0.76   25.4 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6   1110    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 14:56:24 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# m16s6: in try 1/3 found Rhat=1.026
# m16s6 (m16 + spline6)
# Inference for Stan model: m16s6.
# 6 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=6000.
#
#                         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# delta_max              14.18    0.08   2.76  10.62  12.32   13.6  15.36  21.21   1191    1.0
# gamma_mu                1.05  2.1e-3   0.14   0.78   0.95   1.04   1.14   1.32   4229    1.0
# gamma_sigma             0.64  1.7e-3   0.11   0.46   0.56   0.62    0.7   0.89   3956    1.0
# rho_mu                  0.36  1.1e-3   0.06   0.24   0.32   0.36    0.4   0.49   3253    1.0
# rho_sigma               0.28 10.0e-4   0.05    0.2   0.24   0.27    0.3    0.4   2672    1.0
# E_star                  1.55  2.9e-3   0.18   1.22   1.42   1.54   1.66   1.94   3942    1.0
# sigma                 2468.5    1.99  121.5 2235.9 2385.4 2465.8 2547.1 2712.5   3717    1.0
# divrate                 0.38  4.1e-4   0.02   0.35   0.37   0.38   0.39   0.41   1465    1.0
# lp__                  -2.2e6    0.56  26.32 -2.2e6 -2.2e6 -2.2e6 -2.2e6 -2.2e6   2201    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 15:19:48 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# ## plot the results

# %%
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['legend.fontsize'] = 16
mpl.rcParams['axes.titlesize'] = 26
mpl.rcParams['figure.figsize'] = (24,12)
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16

# set the color for each model
num_model = len(mcmcs)
if num_model <= 10:
    colors_model = {model:'C{}'.format(imodel) for imodel,model in enumerate(mcmcs)}
else:
    colors_model = {model:mpl.cm.viridis(imodel/(num_model-1)) for imodel,model in enumerate(mcmcs)}
    
maxrhats_final = {model:{dataname:get_max_rhat(mcmcs[model][dataname]) for dataname in data} for model in mcmcs}

# %%
param_desc = {'divrate':'daily division rate','E_star':'E*'}
# add known values here
reference_values = {'zinser':{'divrate':0.69}}

# %%
ylim_top = 0
for dataname in data:
    for model in mcmcs:
        ylim_top = max(ylim_top, len(maxrhats[model][dataname]))
ylim_top += 1

fig, axs = plt.subplots(nrows=len(data), figsize=(max(24,len(mcmcs)*4.5),len(data)*9), squeeze=False, sharex=True, sharey=True)
for ax,dataname in zip(axs.flat,data):
    xticks = []
    xticklabels = []
    for i,model in enumerate(mcmcs):
        
        height_bad = sum(rh > 1.1 for rh in maxrhats[model][dataname])
        height_good = len(maxrhats[model][dataname]) - height_bad
        
        x = i
        ax.bar(x=x, height=height_bad, color='tab:red', label='max $\\\\hat{R}$ > 1.1')
        ax.bar(x=x, height=height_good, bottom=height_bad, color='tab:green', label='max $\\hat{R} \le$ 1.1')
        
        if len(sampling_time[model][dataname]) != height_bad+height_good:
            print('{}, {}: Timing information inconsistent.'.format(dataname, desc_model[model]))
        else:
            for it, t in enumerate(sampling_time[model][dataname]):
                ax.text(x, it+0.5, '{:.0f}:{:02.0f}'.format(t//60, t%60), ha='center', va='center', size=30)
            
        xticks.append(x)
        xticklabels.append(desc_model[model].replace(',',',\n'))
    
    ax.set(ylabel='number of Stan sampling runs', xticks=xticks, ylim=(0, ylim_top))
    ax.set_title('convergence/$\hat{R}$ statistics for '+desc[dataname], size=20)
    ax.set_xticklabels(xticklabels)#, rotation=8)
    ax.grid(axis='y')

# %%
# updated code can handle all data[dataname]['i_test'] == 0 and draw only a single bar
if np.all(data[dataname]['i_test'] == 0):
    num_bars = 1
else:
    num_bars = 3

height = np.zeros(num_bars)
for dataname in data:
    obs = data[dataname]['obs']
    
    fig, ax = plt.subplots(figsize=(max(24,len(mcmcs)*4.5),9))
    xticks = []
    xticklabels = []
    for i,model in enumerate(mcmcs):
        mod_mean = np.mean(mcmcs[model][dataname]['mod_obspos'], axis=0)
        mod_mean /= np.sum(mod_mean, axis=0)
        
        e = np.sum((mod_mean-obs)**2,axis=0)
        #print(desc_model[model],e)
        
        height[0] = np.mean(e)
        if num_bars > 1:
            height[1] = np.mean(e[data[dataname]['i_test'] == 0])
            height[2] = np.mean(e[data[dataname]['i_test'] == 1])
        
        x = (num_bars+1)*i+np.arange(num_bars)
        ax.bar(x=x, height=height, color=colors_model[model])
        for xx,text in zip(x,['overall mean','training mean','test mean']):
            ax.text(xx, 0, '  '+text, rotation=90, ha='center', va='bottom', size=20)
        if maxrhats_final[model][dataname] > 1.1:
            ax.text(x[num_bars//3], 0, '  no convergence ($\\hat{R}>1.1$)', rotation=45, ha='center', va='bottom', size=30, color='darkred')
        xticks.append(x[num_bars//3])
        xticklabels.append(desc_model[model].replace(',',',\n').replace('(','\n('))
    
    if ax.get_ylim()[1] > 0.005:
        ax.set_ylim(top=0.005)
    ax.set(ylabel='sum of squared column differences', xticks=xticks)
    ax.set_title('model misfit for '+desc[dataname], size=20)
    ax.set_xticklabels(xticklabels)#, rotation=8)
    ax.grid(axis='y')

# %%
if 'size_units' not in globals():
    size_units = 'fg C cell$^{-1}$'

prop_labels = {
    'growth':'cell growth ({} h$^{{-1}}$)'.format(size_units),
    'division':'division rate (h$^{-1}$)',
    'respiration':'respiration + exudation\n({} h$^{{-1}}$)'.format(size_units),
}

for dataname in data:
    
    t = data[dataname]['dt']*np.arange(data[dataname]['nt'])/60.0
    dt_h = data[dataname]['dt']/60.0
    
    for model in mcmcs:
        fig, axs = plt.subplots(nrows=3, figsize=(14,6*3), sharex=True)

        cell_count = mcmcs[model][dataname]['cell_count']
        
        for ax, prop in zip(axs, ('growth', 'division', 'respiration')):

            if prop == 'growth':
                plotprop = mcmcs[model][dataname]['growth_size_gain']/cell_count/dt_h
                x = t
            elif prop == 'division':
                plotprop = (np.log(cell_count[:,1:])-np.log(cell_count[:,:-1]))/(t[1:]-t[:-1])
                x = 0.5 * (t[1:] + t[:-1])
            elif prop == 'respiration':
                plotprop = mcmcs[model][dataname]['resp_size_loss']/cell_count/dt_h
                x = t
            else:
                raise ValueError('Unknown prop "{}".'.format(prop))
            
            qq = np.percentile(plotprop, q=(5,25,50,75,95), axis=0)

            sc = ax.fill_between(x, qq[0,:], qq[-1,:], alpha=0.25, color=colors_model[model])
            ax.fill_between(x, qq[1,:], qq[-2,:], alpha=0.5, facecolor=sc.get_facecolor()[0])
            ax.plot(x, qq[2,:], color=sc.get_facecolor()[0][:-1], lw=2)

            if dataname == 'zinser':
                with nc4.Dataset('data/zinser_growthdivresp.nc') as nc:
                    ax.plot(nc[prop+'/time'][:], np.maximum(0.0, nc[prop+'/'+prop][:]), color='black', marker='o', lw=2)
            
            ax.set_ylim(bottom=0.0)
            ax.set_xlim((0, t[-1]))
            ax.set(ylabel=prop_labels[prop])
            ax.grid(True)
        
        axs[0].set_title(desc_model[model] + ' ' + desc[dataname])
        axs[-1].set(xticks = np.arange(0,t[-1],6), xlabel='time since start of experiment (h)')
        if axs[-1].get_ylim()[-1] < axs[0].get_ylim()[-1]:
            axs[-1].set_ylim(top=axs[0].get_ylim()[-1])

# %%
add_labels = True
for dataname in data:
    if 'zinser' in dataname:
        fig, ax = plt.subplots(figsize=(14,14))
        ax.set_title(desc[dataname], size=20)
        
        for model in mcmcs:
            # misfit to data

            obs = data[dataname]['obs']

            tmp = mcmcs[model][dataname]['mod_obspos']
            tmp/= np.sum(tmp, axis=1)[:,None,:]
            tmp -= obs[None,:,:]
            tmp **= 2
            
            if np.all(data[dataname]['i_test'] == 0):
                e0 = np.mean(np.sum(tmp, axis=1), axis=1)
                xlabel_suffix = ''
            else:
                e0 = np.mean(np.sum(tmp[:,:,data[dataname]['i_test'] == 1], axis=1), axis=1)
                xlabel_suffix = ' (test data)'
            
            # misfit to division rate

            e1 = np.abs(mcmcs[model][dataname]['divrate'] - reference_values[dataname]['divrate'])
        
            q0 = np.percentile(e0, q=(5,25,50,75,95))
            q1 = np.percentile(e1, q=(5,25,50,75,95))
            
            eb = ax.errorbar(x=q0[2], y=q1[2], xerr=np.array((q0[2]-q0[0], q0[-1]-q0[2]))[:,None], marker='o', ms=10, label=desc_model[model], color=colors_model[model])
            ax.errorbar(x=q0[2], y=q1[2], yerr=np.array((q1[2]-q1[0], q1[-1]-q1[2]))[:,None], color=eb[0].get_color())
            
            if add_labels:
                ax.text(q0[2], q1[2], ' '+desc_model[model], color=eb[0].get_color(), size=20)
            
            if maxrhats_final[model][dataname] > 1.1:
                ax.plot(q0[2], q1[2], marker='x', color='darkred', zorder=10, markersize=30, markeredgewidth=3)
        ax.grid(True)
        ax.legend()
        ax.set(xlabel='size distribution misfit'+xlabel_suffix, ylabel='daily division rate misfit')
        ax.set_xlim(left=0.0)
        ax.set_ylim(bottom=0.0)

# %%
datanames = tuple(data.keys())
if len(datanames) > 1:
    fig, ax = plt.subplots(figsize=(14,14))

    for model in mcmcs:
        qq = {}
        # misfit to data
        for dataname in datanames:
            obs = data[dataname]['obs']

            tmp = mcmcs[model][dataname]['mod_obspos']
            tmp/= np.sum(tmp, axis=1)[:,None,:]
            tmp -= obs[None,:,:]
            tmp **= 2

            if np.all(data[dataname]['i_test'] == 0):
                e0 = np.mean(np.sum(tmp, axis=1), axis=1)
            else:
                e0 = np.mean(np.sum(tmp[:,:,data[dataname]['i_test'] == 1], axis=1), axis=1)

            qq[dataname] = np.percentile(e0, q=(5,25,50,75,95))

        q0 = qq[datanames[0]]
        q1 = qq[datanames[1]]

        eb = ax.errorbar(x=q0[2], y=q1[2], xerr=np.array((q0[2]-q0[0], q0[-1]-q0[2]))[:,None], marker='o', ms=10, label=desc_model[model], color=colors_model[model])
        ax.errorbar(x=q0[2], y=q1[2], yerr=np.array((q1[2]-q1[0], q1[-1]-q1[2]))[:,None], color=eb[0].get_color())
        if maxrhats_final[model][dataname] > 1.1:
            ax.plot(q0[2], q1[2], marker='x', color='darkred', zorder=10, markersize=30, markeredgewidth=3)

    ax.grid(True)
    ax.legend()
    ax.set(xlabel='{} size distribution misfit'.format(desc[datanames[0]]), 
           ylabel='{} size distribution misfit'.format(desc[datanames[1]]))
    ax.set_xlim(left=0.0)
    ax.set_ylim(bottom=0.0)
None

# %%
data_fig2a = pd.read_csv('data/Zinser_Figure2A.csv')
t_zinser = data_fig2a['exper time'] * 60
ab_mean_norm = 0.5*(data_fig2a['cells A'].values/data_fig2a['cells A'].values[0] + 
                    data_fig2a['cells B'].values/data_fig2a['cells B'].values[0])

add_labels = True
for dataname in data:
    if 'zinser' in dataname:
        fig, ax = plt.subplots(figsize=(14,14))
        ax.set_title(desc[dataname], size=20)
        
        for model in mcmcs:
            # make sure the time is right, if not implement something fancier
            assert all(t_zinser.values[:-1] == data[dataname]['t_obs'])
            
            # misfit to normalized abundance
            
            e0 = np.mean(np.abs(np.sum(mcmcs[model][dataname]['mod_obspos'], axis=1)[:,1:]-ab_mean_norm[1:-1]), axis=1)
            
            # misfit to division rate

            e1 = np.abs(mcmcs[model][dataname]['divrate'] - reference_values[dataname]['divrate'])
        
            q0 = np.percentile(e0, q=(5,25,50,75,95))
            q1 = np.percentile(e1, q=(5,25,50,75,95))
            
            eb = ax.errorbar(x=q0[2], y=q1[2], xerr=np.array((q0[2]-q0[0], q0[-1]-q0[2]))[:,None], marker='o', ms=10, label=desc_model[model], color=colors_model[model])
            ax.errorbar(x=q0[2], y=q1[2], yerr=np.array((q1[2]-q1[0], q1[-1]-q1[2]))[:,None], color=eb[0].get_color())
            if add_labels:
                ax.text(q0[2], q1[2], ' '+desc_model[model], color=eb[0].get_color(), size=20)
            if maxrhats_final[model][dataname] > 1.1:
                ax.plot(q0[2], q1[2], marker='x', color='darkred', zorder=10, markersize=30, markeredgewidth=3)
        ax.grid(True)
        ax.legend()
        ax.set(xlabel='normalized abundance misfit (hourly division rate)', ylabel='daily division rate misfit')
        ax.set_xlim(left=0.0)
        ax.set_ylim(bottom=0.0)

# %%
for param in ('divrate','E_star'):
    for dataname in data:
        num_mcmcs = len(mcmcs)
        fig, ax = plt.subplots(figsize=(24,3*num_mcmcs))
        ax.set_title('{} for {}'.format(param_desc[param], desc[dataname]))
        ax.violinplot([mcmcs[model][dataname][param] for model in mcmcs], showmedians=True, vert=False)
        ax.invert_yaxis()
        ax.grid(axis='x')
        ax.set(yticks=np.arange(1,num_mcmcs+1), yticklabels=[desc_model[model].replace(',',',\n') for model in mcmcs])
        if dataname in reference_values and param in reference_values[dataname]:
            ax.axvline(reference_values[dataname][param], color='tab:green', lw=3)
        for i,model in enumerate(mcmcs):
            if maxrhats_final[model][dataname] > 1.1:
                ax.text(0.5, i+1, 'no convergence ($\\hat{R}>1.1$)', color='darkred', size=26, transform=ax.get_yaxis_transform(), ha='center', va='center')

# %%
for dataname in data:
    for model,mcmc in mcmcs.items():
        j = data_gridded[dataname]['delta_v_inv'] + 1
        m = data_gridded[dataname]['m']

        fig, ax = plt.subplots(figsize=(20,6))
        ax.set_title(desc_model[model] + '\n' + desc[dataname])
        ax.boxplot(mcmc[dataname]['delta'])
        xlabels = [str(x) for x in range(j,m+1)]
        xlabels[0] = 'j='+xlabels[0]
        xlabels[-1] = 'm='+xlabels[-1]
        ax.set_xticklabels(xlabels)
        ax.grid(axis='y')
        ax.set_ylabel('$\\delta_{max}$')
        
        if maxrhats_final[model][dataname] > 1.1:
            ax.text(0.5, 0.5, 'no convergence ($\\hat{R}>1.1$)', color='darkred', size=26, transform=ax.transAxes, ha='center', va='center')
        None

# %%
data_fig2a = pd.read_csv('data/Zinser_Figure2A.csv')

t_zinser = data_fig2a['exper time'] * 60
a_norm = data_fig2a['cells A'].copy()
a_norm /= a_norm[0]
b_norm = data_fig2a['cells B'].copy()
b_norm /= b_norm[0]

colors = {'model':'darkred', 'obs':'0.1'}

norm = mpl.colors.Normalize(0.0,0.15)
norm_diff = mpl.colors.Normalize(-0.1,0.1)

for dataname in data:
    t = data[dataname]['dt']*np.arange(data[dataname]['nt'])
    delta_v = 1.0/data_gridded[dataname]['delta_v_inv']
    v_ext = data[dataname]['v_min'] * 2**(np.arange(data[dataname]['m']+1)*delta_v) 
    v = v_ext[:-1]
    v_width = v_ext[1:] - v_ext[:-1]
        
    for model,mcmc in mcmcs.items():
        
        res = {'model':np.mean(mcmc[dataname]['mod_obspos'], axis=0), 'obs':data[dataname]['obs']}
        res_sum1 = res['model']/np.sum(res['model'], axis=0)[None,:]
        diff = res_sum1-res['obs']

        if maxrhats_final[model][dataname] > 1.1:
            fig, ax = plt.subplots(figsize=(24,4))
            ax.set_title(desc_model[model] + '\n' + desc[dataname])
            ax.set(xticks=[], yticks=[])
            ax.text(0.5, 0.5, 'no convergence ($\\hat{R}>1.1$)', color='darkred', size=26, transform=ax.transAxes, ha='center', va='center')
            continue
        
        fig,axs = plt.subplots(6,1,sharex=True,figsize=(24,40))
        axs[0].set_title(desc_model[model] + '\n' + desc[dataname])

        ax = axs[0]
        ax.plot(t, data[dataname]['E'], color='gold')
        ax.set(xlim=(data[dataname]['t_obs'][0],t[-1]), ylabel='PAR')

        ax = axs[1]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, res['obs'],norm=norm, shading='auto')
        ax.set(ylabel='size ({})'.format(size_units), title='size distribution data')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='size class proportion')

        ax = axs[2]
        ax.set(ylabel='size ({})'.format(size_units), title='size distribution model posterior')
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, res_sum1,norm=norm, shading='auto')

        ax = axs[3]
        pc = ax.pcolormesh(data[dataname]['t_obs'], v, diff,norm=norm_diff, cmap='PiYG', shading='auto')
        ax.set(ylabel='size ({})'.format(size_units), title='model - data misfit')
        add_colorbar(ax, norm=pc.norm, cmap=pc.cmap, label='difference in size class proportion')
        
        qq = np.percentile(np.sum(mcmc[dataname]['mod_obspos'], axis=1), axis=0, q=(5,25,50,75,95))
    
        ax = axs[4]
        ax.fill_between(data[dataname]['t_obs'], qq[0,:], qq[-1,:], alpha=0.25, color='gold')
        ax.fill_between(data[dataname]['t_obs'], qq[1,:], qq[-2,:], alpha=0.5, color='gold')
        ax.plot(data[dataname]['t_obs'], qq[2,:], color='gold')
        if 'zinser' in dataname:
            ax.plot(t_zinser, a_norm, color='black', marker='s', label='Zinser normalized "cells A"')
            ax.plot(t_zinser, b_norm, color='red', marker='^', label='Zinser normalized "cells B"')
            for iday in range(2):
                ax.axvspan(iday*24*60+12*60, iday*24*60+22*60, color='0.7', zorder=0)
            ax.legend()
        ax.grid(True)
        ax.set(ylabel='sum across size classes', title='relative increase in population size (division)')

        ax = axs[5]
        prop = np.mean(np.abs(diff),axis=0)
        ax.plot(data[dataname]['t_obs'], prop, label='mean(abs(diff)), avg: {:.6f}'.format(np.mean(prop)))
        prop = np.sum(diff**2,axis=0)
        ax.plot(data[dataname]['t_obs'], prop, label='sum(diff$^2$), avg: {:.6f}'.format(np.mean(prop)))
        ax.set(xlabel='time (minutes)', ylabel='model-observation misfit')
        ax.grid(True)
        ax.legend()

# %%
if 'varnames_save' not in globals():
    varnames_save = None

save_only_converged = True

if savename_output is not None:    
    with nc4.Dataset(savename_output, 'w') as nc:
        for dataname in data:
            ncg = nc.createGroup(dataname)

            if save_stan_output:
                dimensions = {
                    'obstime':int(data[dataname]['nt_obs']),
                    'time':int(data[dataname]['nt']),
                    'sizeclass':int(data[dataname]['m']),
                    'm_minus_j_plus_1':int(data[dataname]['m']-data[dataname]['delta_v_inv']),
                }
                dimensions_inv = {v:k for k,v in dimensions.items()}
                for d in dimensions:
                    ncg.createDimension(d, dimensions[d])
                    
                ncg.createVariable('time', int, ('time',))
                ncg.variables['time'][:] = int(data[dataname]['dt']) * np.arange(data[dataname]['nt'])
                ncg.variables['time'].units = 'minutes since start of experiment'
                
                ncg.createVariable('obstime', int, ('obstime',))
                ncg.variables['obstime'][:] = data[dataname]['t_obs'].astype(int)
                ncg.variables['obstime'].units = 'minutes since start of experiment'
                ncg.variables['obstime'].long_name = 'time of observations'

                for v in ('dt', 'm', 'v_min', 'delta_v_inv', 'obs', 'i_test', 'E', 'obs_count'):
                    if isinstance(data[dataname][v], int):
                        ncg.createVariable(v, int, zlib=True)
                        ncg.variables[v][:] = data[dataname][v]
                    elif isinstance(data[dataname][v], float):
                        ncg.createVariable(v, float, zlib=True)
                        ncg.variables[v][:] = data[dataname][v]
                    else:
                        dims = tuple(dimensions_inv[d] for d in data[dataname][v].shape)
                        ncg.createVariable(v, data[dataname][v].dtype, dims, zlib=True)
                        ncg.variables[v][:] = data[dataname][v]
                
                for imodel,model in enumerate(mcmcs):
                    if save_only_converged and get_max_rhat(mcmcs[model][dataname]) > 1.1:
                        logging.warning('Model "{}" did not converge -- skipping.'.format(model))
                        continue
                    ncm = ncg.createGroup(model)
                    
                    dimensions['sample'] = mcmcs[model][dataname]['mod_obspos'].shape[0]
                    dimensions_inv[dimensions['sample']] = 'sample'
                    ncm.createDimension('sample', dimensions['sample'])
                    if 'tau[1]' in mcmcs[model][dataname].flatnames:
                        dimensions['tau'] = mcmcs[model][dataname]['tau'].shape[1]
                        dimensions_inv[dimensions['tau']] = 'tau'
                        ncm.createDimension('tau', dimensions['tau'])
                    if 'tau_control[1]' in mcmcs[model][dataname].flatnames:
                        dimensions['tau_control'] = mcmcs[model][dataname]['tau_control'].shape[1]
                        dimensions_inv[dimensions['tau_control']] = 'tau_control'
                        ncm.createDimension('tau_control', dimensions['tau_control'])
                    
                    # write model description
                    ncm.setncattr('description', desc_model[model])
                    ncm.setncattr('code', stan_files[model_stan_key[model]])
                    
                    varnames = set(v.split('[')[0] for v in mcmcs[model][dataname].flatnames)
                    if varnames_save is None:
                        varnames_curr = varnames
                    else:
                        varnames_curr = varnames_save
                        
                    for v in varnames_curr:
                        if v in varnames:
                            dims = tuple(dimensions_inv[d] for d in mcmcs[model][dataname][v].shape)
                            ncm.createVariable(v, float, dims, zlib=True)
                            ncm.variables[v][:] = mcmcs[model][dataname][v]
                        else:
                            logging.warning('Cannot find variable "{}" for model "{}".'.format(v, model))
            else:
                for i,model in enumerate(mcmcs):
                    if i == 0:
                        ncg.createDimension('model', len(mcmcs))
                        ncg.createDimension('sample', mcmcs[model][dataname]['divrate'].shape[0])

                        ncg.createVariable('divrate', float, ('model','sample'))
                        ncg.createVariable('sumsqdiff', float, ('model','sample'))
                        ncg.variables['sumsqdiff'].setncattr('long_name', 'sum of squared column differences')

                    ncg.variables['divrate'][i,:] = mcmcs[model][dataname]['divrate']

                    obs = data[dataname]['obs']

                    tmp = mcmcs[model][dataname]['mod_obspos']
                    tmp/= np.sum(tmp, axis=1)[:,None,:]
                    tmp -= obs[None,:,:]
                    tmp **= 2

                    if np.all(data[dataname]['i_test'] == 0):
                        ncg.variables['sumsqdiff'][i,:] = np.mean(np.sum(tmp, axis=1), axis=1)
                        if i == 0:
                            ncg.variables['sumsqdiff'].setncattr('data_used', 'all data')
                    else:
                        nc.variables['sumsqdiff'][i,:] = np.mean(np.sum(tmp[:,:,data[dataname]['i_test'] == 1], axis=1), axis=1)
                        if i == 0:
                            ncg.variables['sumsqdiff'].setncattr('data_used', 'testing data')

                    for iv,v in enumerate(('gamma_max','rho_max','xi','xir','E_star')):
                        if i == 0:
                            ncg.createVariable(v, float, ('model','sample'))
                        if v in mcmcs[model][dataname].flatnames:
                            ncg.variables[v][i,:] = mcmcs[model][dataname][v]
# Out:
# WARNING:root:Model "m4" did not converge -- skipping.
# WARNING:root:Model "m12u" did not converge -- skipping.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f9a33e448058> in <module>
#      71                     for v in varnames_curr:
#      72                         if v in varnames:
# ---> 73                             dims = tuple(dimensions_inv[d] for d in mcmcs[model][dataname][v].shape)
#      74                             ncm.createVariable(v, float, dims, zlib=True)
#      75                             ncm.variables[v][:] = mcmcs[model][dataname][v]
#
# <ipython-input-20-f9a33e448058> in <genexpr>(.0)
#      71                     for v in varnames_curr:
#      72                         if v in varnames:
# ---> 73                             dims = tuple(dimensions_inv[d] for d in mcmcs[model][dataname][v].shape)
#      74                             ncm.createVariable(v, float, dims, zlib=True)
#      75                             ncm.variables[v][:] = mcmcs[model][dataname][v]
#
# KeyError: 24
